# %%
from catboost import CatBoostClassifier
import pandas as pd

# %%
df = pd.read_csv('star_classification.csv')

# %%
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# 1  GALAXY  0.779136  10445  58158       427
# 2  GALAXY  0.644195   4576  55592       299
# 3  GALAXY  0.932346   9149  58039       775
# 4  GALAXY  0.116123   6121  56187       842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# 25%        18.965230      18.135828      17.732285      17.460677
# 50%        21.099835      20.125290      19.405145      19.004595
# 75%        22.123767      21.044785      20.396495      19.921120
# max        31.602240      29.571860      32.141470      29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000

# %%
X = df.drop(['rerun_ID'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# X = df
y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.75, 
                                                    random_state=42)

# %%
# X_train.head()
X_test2 = X_test.drop('class', axis=1)
X_test2.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD',
#        'fiber_ID'],
#       dtype='object')

# %%
y_train.head()
# Out:
# 98980    GALAXY
# 69824      STAR
# 9928     GALAXY
# 75599    GALAXY
# 95621       QSO
# Name: class, dtype: object

# %% [markdown]
# ## Background
#
# This dataset contains over 100,000 observations separated into three class types: Galaxies, Quasars, and Stars. In addition to the class,
# each observation has 17 other defining features, several of which are different identification types that were irrelevant for the purposes
# of this analysis. For completeness, I will list them all where now:
#
# * obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS.
#
# * alpha = Right Ascension angle (at J2000 epoch). This is the angle (in degrees) between the Vernal Equinox
# and the desired point on the celestial sphere.
#
# * delta = Declination angle (at J2000 epoch). The is the angle (in degrees) between the celestial equator and
# the desired point on the celestial sphere.
#
# * u = Ultraviolet filter in the photometric system. 3543 Angstroms (354.3 nm)
#
# * g = Green filter in the photometric system. 4770 Angstroms (477.0 nm)
#
# * r = Red filter in the photometric system. 6231 Angstroms (623.1 nm)
#
# * i = Near Infrared filter in the photometric system. 7625 Angstroms (762.5 nm)
#
# * z = Infrared filter in the photometric system. 9134 Angstroms (913.4 nm)
#
# * run_ID = Run Number used to identify the specific scan.
#
# * rereun_ID = Rerun Number to specify how the image was processed.
#
# * cam_col = Camera column to identify the scanline within the run.
#
# * field_ID = Field number to identify each field.
#
# * spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class).
#
# * class = Object class (galaxy, star, or quasar object).
#
# * redshift = Redshift value based on the increase in wavelength. The more red shifted light is, the further it has traveled from its
# point of origin
#
# * plate = Plate ID, identifies each plate in SDSS.
#
# * MJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken.
#
# * fiber_ID = Fiber ID that identifies the fiber that pointed the light at the focal plane in each observation.
#
# As explained earlier, the ID attributes were removed from the table before I began looking for trends.

# %%
model = CatBoostClassifier(iterations=12,
                           learning_rate=1,
                           depth=3)
# Fit model
train_label = ['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',  
               'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD', 'fiber_ID']
num_feature=[]

model.fit(X_train, y_train)
# Get predicted classes
preds_class = model.predict(eval_data)
# Get predicted probabilities for each class
#preds_proba = model.predict_proba(eval_data)
# Get predicted RawFormulaVal
#preds_raw = model.predict(eval_data, prediction_type='RawFormulaVal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File _catboost.pyx:2288, in _catboost.get_float_feature()
#
# File _catboost.pyx:1141, in _catboost._FloatOrNan()
#
# File _catboost.pyx:951, in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'GALAXY'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# Cell In[33], line 9
#       4 # Fit model
#       5 train_label = ['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID', 'rerun_ID',
#       6                'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD', 'fiber_ID']
# ----> 9 model.fit(X_train, y_train)
#      10 # Get predicted classes
#      11 preds_class = model.predict(eval_data)
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:5131, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5128 if 'loss_function' in params:
#    5129     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5131 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5132           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5133           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5134 return self
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:2341, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2338 if y is None and not isinstance(X, PATH_TYPES + (Pool,)):
#    2339     raise CatBoostError("y may be None only when X is an instance of catboost.Pool or string")
# -> 2341 train_params = self._prepare_train_params(
#    2342     X=X, y=y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features,
#    2343     pairs=pairs, sample_weight=sample_weight, group_id=group_id, group_weight=group_weight,
#    2344     subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline, use_best_model=use_best_model,
#    2345     eval_set=eval_set, verbose=verbose, logging_level=logging_level, plot=plot, plot_file=plot_file,
#    2346     column_description=column_description, verbose_eval=verbose_eval, metric_period=metric_period,
#    2347     silent=silent, early_stopping_rounds=early_stopping_rounds, save_snapshot=save_snapshot,
#    2348     snapshot_file=snapshot_file, snapshot_interval=snapshot_interval, init_model=init_model,
#    2349     callbacks=callbacks
#    2350 )
#    2351 params = train_params["params"]
#    2352 train_pool = train_params["train_pool"]
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:2222, in CatBoost._prepare_train_params(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks)
#    2219 text_features = _process_feature_indices(text_features, X, params, 'text_features')
#    2220 embedding_features = _process_feature_indices(embedding_features, X, params, 'embedding_features')
# -> 2222 train_pool = _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs,
#    2223                                sample_weight, group_id, group_weight, subgroup_id, pairs_weight,
#    2224                                baseline, column_description)
#    2225 if train_pool.is_empty_:
#    2226     raise CatBoostError("X is empty.")
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:1438, in _build_train_pool(X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1436     if y is None:
#    1437         raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
# -> 1438     train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, embedding_features=embedding_features, pairs=pairs, weight=sample_weight, group_id=group_id,
#    1439                       group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#    1440 return train_pool
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:792, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     786         if isinstance(feature_names, PATH_TYPES):
#     787             raise CatBoostError(
#     788                 "feature_names must be None or have non-string type when the pool is created from "
#     789                 "python objects."
#     790             )
# --> 792         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     793                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     794 super(Pool, self).__init__()
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:1419, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1417 if feature_tags is not None:
#    1418     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1419 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1420                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3955, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4005, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3821, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2787, in _catboost._set_features_order_data_pd_data_frame()
#
# File _catboost.pyx:2329, in _catboost.create_num_factor_data()
#
# File _catboost.pyx:2290, in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=12]="GALAXY": Cannot convert 'b'GALAXY'' to float
