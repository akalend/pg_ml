# %%
from catboost import CatBoostClassifier
import pandas as pd

# %%
df = pd.read_csv('star_classification.csv')

# %%
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# 1  GALAXY  0.779136  10445  58158       427
# 2  GALAXY  0.644195   4576  55592       299
# 3  GALAXY  0.932346   9149  58039       775
# 4  GALAXY  0.116123   6121  56187       842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %% [markdown]
# ## Background
#
# This dataset contains over 100,000 observations separated into three class types: Galaxies, Quasars, and Stars. In addition to the class,
# each observation has 17 other defining features, several of which are different identification types that were irrelevant for the purposes
# of this analysis. For completeness, I will list them all where now:
#
# * obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS.
#
# * alpha = Right Ascension angle (at J2000 epoch). This is the angle (in degrees) between the Vernal Equinox
# and the desired point on the celestial sphere.
#
# * delta = Declination angle (at J2000 epoch). The is the angle (in degrees) between the celestial equator and
# the desired point on the celestial sphere.
#
# * u = Ultraviolet filter in the photometric system. 3543 Angstroms (354.3 nm)
#
# * g = Green filter in the photometric system. 4770 Angstroms (477.0 nm)
#
# * r = Red filter in the photometric system. 6231 Angstroms (623.1 nm)
#
# * i = Near Infrared filter in the photometric system. 7625 Angstroms (762.5 nm)
#
# * z = Infrared filter in the photometric system. 9134 Angstroms (913.4 nm)
#
# * run_ID = Run Number used to identify the specific scan.
#
# * rereun_ID = Rerun Number to specify how the image was processed.
#
# * cam_col = Camera column to identify the scanline within the run.
#
# * field_ID = Field number to identify each field.
#
# * spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class).
#
# * class = Object class (galaxy, star, or quasar object).
#
# * redshift = Redshift value based on the increase in wavelength. The more red shifted light is, the further it has traveled from its
# point of origin
#
# * plate = Plate ID, identifies each plate in SDSS.
#
# * MJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken.
#
# * fiber_ID = Fiber ID that identifies the fiber that pointed the light at the focal plane in each observation.
#
# As explained earlier, the ID attributes were removed from the table before I began looking for trends.

# %%
df.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# 25%        18.965230      18.135828      17.732285      17.460677
# 50%        21.099835      20.125290      19.405145      19.004595
# 75%        22.123767      21.044785      20.396495      19.921120
# max        31.602240      29.571860      32.141470      29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000

# %%
# уничтожаем так как одно и тоже число
X = df.drop(['rerun_ID'], axis=1)

# %%
from sklearn.model_selection import train_test_split

y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.75, 
                                                    random_state=42)

# %%
# X_train.head()
X_test2 = X_test.drop('class', axis=1)
X_test2.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD',
#        'fiber_ID'],
#       dtype='object')

# %%
from catboost import FeaturesData

# %%
# model = CatBoostClassifier( loss_function='MultiLogloss',
#                             eval_metric='HammingLoss',
#                            random_seed=21,
#                             iterations=500,
#                             class_names=['GALAXY', 'QSO', 'STAR'])
# # Fit model
train_label = ['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',  
               'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD', 'fiber_ID']
cat_features = [ 'run_ID',  'cam_col', 'field_ID', 'plate', 'MJD', 'fiber_ID']

# Get predicted probabilities for each class
#preds_proba = model.predict_proba(eval_data)
# Get predicted RawFormulaVal
#preds_raw = model.predict(eval_data, prediction_type='RawFormulaVal')

# %%
model = CatBoostClassifier(cat_features=['class'] ) # классификатор
model.fit(X_train, y_train) # обучение классификатора
# Out:
# Learning rate set to 0.098617
# 0:	learn: 0.9122489	total: 147ms	remaining: 2m 26s
# 1:	learn: 0.7732497	total: 242ms	remaining: 2m
# 2:	learn: 0.6639896	total: 308ms	remaining: 1m 42s
# 3:	learn: 0.5759337	total: 383ms	remaining: 1m 35s
# 4:	learn: 0.5031165	total: 466ms	remaining: 1m 32s
# 5:	learn: 0.4419333	total: 554ms	remaining: 1m 31s
# 6:	learn: 0.3899735	total: 648ms	remaining: 1m 31s
# 7:	learn: 0.3454694	total: 697ms	remaining: 1m 26s
# 8:	learn: 0.3067920	total: 789ms	remaining: 1m 26s
# 9:	learn: 0.2732069	total: 837ms	remaining: 1m 22s
# 10:	learn: 0.2437343	total: 861ms	remaining: 1m 17s
# 11:	learn: 0.2179067	total: 907ms	remaining: 1m 14s
# 12:	learn: 0.1951059	total: 968ms	remaining: 1m 13s
# 13:	learn: 0.1749122	total: 1s	remaining: 1m 10s
# 14:	learn: 0.1570169	total: 1.04s	remaining: 1m 8s
# 15:	learn: 0.1410932	total: 1.08s	remaining: 1m 6s
# 16:	learn: 0.1269432	total: 1.13s	remaining: 1m 5s
# 17:	learn: 0.1142942	total: 1.18s	remaining: 1m 4s
# 18:	learn: 0.1029872	total: 1.23s	remaining: 1m 3s
# 19:	learn: 0.0928440	total: 1.29s	remaining: 1m 3s
# 20:	learn: 0.0837640	total: 1.34s	remaining: 1m 2s
# 21:	learn: 0.0755964	total: 1.39s	remaining: 1m 1s
# 22:	learn: 0.0682900	total: 1.44s	remaining: 1m 1s
# 23:	learn: 0.0617095	total: 1.48s	remaining: 1m
# 24:	learn: 0.0558217	total: 1.53s	remaining: 59.8s
# 25:	learn: 0.0504940	total: 1.6s	remaining: 59.8s
# 26:	learn: 0.0456524	total: 1.63s	remaining: 58.7s
# 27:	learn: 0.0412983	total: 1.67s	remaining: 58s
# 28:	learn: 0.0373639	total: 1.71s	remaining: 57.4s
# 29:	learn: 0.0338474	total: 1.76s	remaining: 56.9s
# 30:	learn: 0.0306335	total: 1.79s	remaining: 56s
# 31:	learn: 0.0277526	total: 1.85s	remaining: 56.1s
# 32:	learn: 0.0251645	total: 1.91s	remaining: 56s
# 33:	learn: 0.0228438	total: 1.96s	remaining: 55.6s
# 34:	learn: 0.0207137	total: 2s	remaining: 55.2s
# 35:	learn: 0.0188052	total: 2.05s	remaining: 54.9s
# 36:	learn: 0.0170965	total: 2.12s	remaining: 55.2s
# 37:	learn: 0.0155359	total: 2.17s	remaining: 54.9s
# 38:	learn: 0.0141162	total: 2.22s	remaining: 54.7s
# 39:	learn: 0.0128532	total: 2.27s	remaining: 54.4s
# 40:	learn: 0.0117062	total: 2.31s	remaining: 54.1s
# 41:	learn: 0.0106316	total: 2.37s	remaining: 54s
# 42:	learn: 0.0096777	total: 2.42s	remaining: 53.8s
# 43:	learn: 0.0087811	total: 2.48s	remaining: 53.9s
# 44:	learn: 0.0080036	total: 2.56s	remaining: 54.3s
# 45:	learn: 0.0073351	total: 2.65s	remaining: 55s
# 46:	learn: 0.0066891	total: 2.73s	remaining: 55.4s
# 47:	learn: 0.0060952	total: 2.81s	remaining: 55.8s
# 48:	learn: 0.0055471	total: 2.88s	remaining: 55.9s
# 49:	learn: 0.0050414	total: 2.93s	remaining: 55.6s
# 50:	learn: 0.0045856	total: 2.97s	remaining: 55.2s
# 51:	learn: 0.0041799	total: 3.05s	remaining: 55.7s
# 52:	learn: 0.0038150	total: 3.14s	remaining: 56.2s
# 53:	learn: 0.0034873	total: 3.24s	remaining: 56.7s
# 54:	learn: 0.0031784	total: 3.33s	remaining: 57.3s
# 55:	learn: 0.0029050	total: 3.41s	remaining: 57.6s
# 56:	learn: 0.0026587	total: 3.46s	remaining: 57.3s
# 57:	learn: 0.0024402	total: 3.5s	remaining: 56.9s
# 58:	learn: 0.0022349	total: 3.55s	remaining: 56.6s
# 59:	learn: 0.0020504	total: 3.6s	remaining: 56.3s
# 60:	learn: 0.0018854	total: 3.68s	remaining: 56.6s
# 61:	learn: 0.0017309	total: 3.78s	remaining: 57.2s
# 62:	learn: 0.0015911	total: 3.87s	remaining: 57.5s
# 63:	learn: 0.0014564	total: 3.95s	remaining: 57.8s
# 64:	learn: 0.0013384	total: 4.03s	remaining: 57.9s
# 65:	learn: 0.0012244	total: 4.1s	remaining: 58.1s
# 66:	learn: 0.0011222	total: 4.16s	remaining: 58s
# 67:	learn: 0.0010313	total: 4.23s	remaining: 57.9s
# 68:	learn: 0.0009449	total: 4.3s	remaining: 58.1s
# 69:	learn: 0.0008742	total: 4.4s	remaining: 58.5s
# 70:	learn: 0.0008054	total: 4.46s	remaining: 58.4s
# 71:	learn: 0.0007505	total: 4.53s	remaining: 58.4s
# 72:	learn: 0.0006996	total: 4.62s	remaining: 58.7s
# 73:	learn: 0.0006508	total: 4.69s	remaining: 58.7s
# 74:	learn: 0.0006016	total: 4.73s	remaining: 58.4s
# 75:	learn: 0.0005697	total: 4.77s	remaining: 58s
# 76:	learn: 0.0005305	total: 4.81s	remaining: 57.7s
# 77:	learn: 0.0004921	total: 4.86s	remaining: 57.4s
# 78:	learn: 0.0004608	total: 4.91s	remaining: 57.2s
# 79:	learn: 0.0004293	total: 4.94s	remaining: 56.9s
# 80:	learn: 0.0004134	total: 4.99s	remaining: 56.6s
# 81:	learn: 0.0003982	total: 5.03s	remaining: 56.3s
# 82:	learn: 0.0003775	total: 5.07s	remaining: 56s
# 83:	learn: 0.0003576	total: 5.12s	remaining: 55.8s
# 84:	learn: 0.0003359	total: 5.16s	remaining: 55.5s
# 85:	learn: 0.0003140	total: 5.2s	remaining: 55.2s
# 86:	learn: 0.0002920	total: 5.23s	remaining: 54.9s
# 87:	learn: 0.0002838	total: 5.27s	remaining: 54.6s
# 88:	learn: 0.0002695	total: 5.31s	remaining: 54.4s
# 89:	learn: 0.0002565	total: 5.35s	remaining: 54.1s
# 90:	learn: 0.0002459	total: 5.39s	remaining: 53.9s
# 91:	learn: 0.0002325	total: 5.43s	remaining: 53.6s
# 92:	learn: 0.0002230	total: 5.47s	remaining: 53.4s
# 93:	learn: 0.0002138	total: 5.54s	remaining: 53.4s
# 94:	learn: 0.0002031	total: 5.62s	remaining: 53.6s
# 95:	learn: 0.0001968	total: 5.72s	remaining: 53.9s
# 96:	learn: 0.0001915	total: 5.79s	remaining: 54s
# 97:	learn: 0.0001859	total: 5.86s	remaining: 53.9s
# 98:	learn: 0.0001823	total: 5.94s	remaining: 54s
# 99:	learn: 0.0001737	total: 6.02s	remaining: 54.1s
# 100:	learn: 0.0001670	total: 6.09s	remaining: 54.2s
# 101:	learn: 0.0001579	total: 6.15s	remaining: 54.2s
# 102:	learn: 0.0001511	total: 6.23s	remaining: 54.3s
# 103:	learn: 0.0001427	total: 6.28s	remaining: 54.1s
# 104:	learn: 0.0001350	total: 6.32s	remaining: 53.9s
# 105:	learn: 0.0001323	total: 6.37s	remaining: 53.7s
# 106:	learn: 0.0001276	total: 6.43s	remaining: 53.7s
# 107:	learn: 0.0001220	total: 6.46s	remaining: 53.4s
# 108:	learn: 0.0001196	total: 6.51s	remaining: 53.2s
# 109:	learn: 0.0001151	total: 6.54s	remaining: 52.9s
# 110:	learn: 0.0001119	total: 6.58s	remaining: 52.7s
# 111:	learn: 0.0001081	total: 6.63s	remaining: 52.6s
# 112:	learn: 0.0001047	total: 6.67s	remaining: 52.4s
# 113:	learn: 0.0001041	total: 6.72s	remaining: 52.2s
# 114:	learn: 0.0001021	total: 6.76s	remaining: 52s
# 115:	learn: 0.0000988	total: 6.8s	remaining: 51.8s
# 116:	learn: 0.0000969	total: 6.85s	remaining: 51.7s
# 117:	learn: 0.0000945	total: 6.89s	remaining: 51.5s
# 118:	learn: 0.0000904	total: 6.93s	remaining: 51.3s
# 119:	learn: 0.0000866	total: 6.96s	remaining: 51.1s
# 120:	learn: 0.0000840	total: 7s	remaining: 50.8s
# 121:	learn: 0.0000831	total: 7.05s	remaining: 50.8s
# 122:	learn: 0.0000816	total: 7.09s	remaining: 50.6s
# 123:	learn: 0.0000815	total: 7.13s	remaining: 50.4s
# 124:	learn: 0.0000814	total: 7.18s	remaining: 50.3s
# 125:	learn: 0.0000799	total: 7.22s	remaining: 50.1s
# 126:	learn: 0.0000768	total: 7.25s	remaining: 49.9s
# 127:	learn: 0.0000748	total: 7.3s	remaining: 49.7s
# 128:	learn: 0.0000720	total: 7.34s	remaining: 49.5s
# 129:	learn: 0.0000708	total: 7.38s	remaining: 49.4s
# 130:	learn: 0.0000706	total: 7.44s	remaining: 49.4s
# 131:	learn: 0.0000688	total: 7.5s	remaining: 49.3s
# 132:	learn: 0.0000675	total: 7.57s	remaining: 49.3s
# 133:	learn: 0.0000657	total: 7.64s	remaining: 49.4s
# 134:	learn: 0.0000644	total: 7.72s	remaining: 49.5s
# 135:	learn: 0.0000633	total: 7.78s	remaining: 49.4s
# 136:	learn: 0.0000617	total: 7.82s	remaining: 49.3s
# 137:	learn: 0.0000616	total: 7.87s	remaining: 49.1s
# 138:	learn: 0.0000608	total: 7.91s	remaining: 49s
# 139:	learn: 0.0000595	total: 7.96s	remaining: 48.9s
# 140:	learn: 0.0000588	total: 8s	remaining: 48.7s
# 141:	learn: 0.0000576	total: 8.04s	remaining: 48.6s
# 142:	learn: 0.0000564	total: 8.1s	remaining: 48.5s
# 143:	learn: 0.0000564	total: 8.17s	remaining: 48.5s
# 144:	learn: 0.0000555	total: 8.26s	remaining: 48.7s
# 145:	learn: 0.0000549	total: 8.33s	remaining: 48.7s
# 146:	learn: 0.0000538	total: 8.37s	remaining: 48.6s
# 147:	learn: 0.0000530	total: 8.42s	remaining: 48.5s
# 148:	learn: 0.0000530	total: 8.46s	remaining: 48.4s
# 149:	learn: 0.0000514	total: 8.5s	remaining: 48.2s
# 150:	learn: 0.0000514	total: 8.55s	remaining: 48s
# 151:	learn: 0.0000506	total: 8.64s	remaining: 48.2s
# 152:	learn: 0.0000497	total: 8.71s	remaining: 48.2s
# 153:	learn: 0.0000489	total: 8.76s	remaining: 48.1s
# 154:	learn: 0.0000476	total: 8.79s	remaining: 47.9s
# 155:	learn: 0.0000467	total: 8.83s	remaining: 47.8s
# 156:	learn: 0.0000460	total: 8.88s	remaining: 47.7s
# 157:	learn: 0.0000450	total: 8.92s	remaining: 47.5s
# 158:	learn: 0.0000442	total: 8.96s	remaining: 47.4s
# 159:	learn: 0.0000436	total: 8.99s	remaining: 47.2s
# 160:	learn: 0.0000429	total: 9.03s	remaining: 47.1s
# 161:	learn: 0.0000420	total: 9.07s	remaining: 46.9s
# 162:	learn: 0.0000415	total: 9.12s	remaining: 46.8s
# 163:	learn: 0.0000405	total: 9.16s	remaining: 46.7s
# 164:	learn: 0.0000397	total: 9.2s	remaining: 46.6s
# 165:	learn: 0.0000388	total: 9.24s	remaining: 46.4s
# 166:	learn: 0.0000380	total: 9.28s	remaining: 46.3s
# 167:	learn: 0.0000380	total: 9.32s	remaining: 46.2s
# 168:	learn: 0.0000374	total: 9.37s	remaining: 46.1s
# 169:	learn: 0.0000369	total: 9.41s	remaining: 46s
# 170:	learn: 0.0000361	total: 9.45s	remaining: 45.8s
# 171:	learn: 0.0000361	total: 9.48s	remaining: 45.7s
# 172:	learn: 0.0000361	total: 9.54s	remaining: 45.6s
# 173:	learn: 0.0000354	total: 9.58s	remaining: 45.5s
# 174:	learn: 0.0000347	total: 9.62s	remaining: 45.4s
# 175:	learn: 0.0000346	total: 9.67s	remaining: 45.3s
# 176:	learn: 0.0000346	total: 9.71s	remaining: 45.1s
# 177:	learn: 0.0000339	total: 9.75s	remaining: 45s
# 178:	learn: 0.0000334	total: 9.79s	remaining: 44.9s
# 179:	learn: 0.0000331	total: 9.84s	remaining: 44.8s
# 180:	learn: 0.0000326	total: 9.88s	remaining: 44.7s
# 181:	learn: 0.0000321	total: 9.92s	remaining: 44.6s
# 182:	learn: 0.0000319	total: 9.96s	remaining: 44.5s
# 183:	learn: 0.0000319	total: 10s	remaining: 44.4s
# 184:	learn: 0.0000314	total: 10.1s	remaining: 44.3s
# 185:	learn: 0.0000309	total: 10.1s	remaining: 44.2s
# 186:	learn: 0.0000307	total: 10.2s	remaining: 44.1s
# 187:	learn: 0.0000303	total: 10.2s	remaining: 44.1s
# 188:	learn: 0.0000298	total: 10.2s	remaining: 44s
# 189:	learn: 0.0000295	total: 10.3s	remaining: 43.9s
# 190:	learn: 0.0000291	total: 10.3s	remaining: 43.8s
# 191:	learn: 0.0000289	total: 10.4s	remaining: 43.7s
# 192:	learn: 0.0000285	total: 10.4s	remaining: 43.6s
# 193:	learn: 0.0000283	total: 10.5s	remaining: 43.5s
# 194:	learn: 0.0000280	total: 10.5s	remaining: 43.4s
# 195:	learn: 0.0000277	total: 10.6s	remaining: 43.3s
# 196:	learn: 0.0000276	total: 10.6s	remaining: 43.2s
# 197:	learn: 0.0000272	total: 10.7s	remaining: 43.1s
# 198:	learn: 0.0000268	total: 10.7s	remaining: 43s
# 199:	learn: 0.0000268	total: 10.7s	remaining: 42.9s
# 200:	learn: 0.0000264	total: 10.8s	remaining: 42.8s
# 201:	learn: 0.0000263	total: 10.8s	remaining: 42.7s
# 202:	learn: 0.0000263	total: 10.9s	remaining: 42.6s
# 203:	learn: 0.0000259	total: 10.9s	remaining: 42.6s
# 204:	learn: 0.0000258	total: 11s	remaining: 42.5s
# 205:	learn: 0.0000255	total: 11s	remaining: 42.4s
# 206:	learn: 0.0000255	total: 11s	remaining: 42.2s
# 207:	learn: 0.0000253	total: 11.1s	remaining: 42.1s
# 208:	learn: 0.0000251	total: 11.1s	remaining: 42.1s
# 209:	learn: 0.0000250	total: 11.2s	remaining: 41.9s
# 210:	learn: 0.0000250	total: 11.2s	remaining: 41.9s
# 211:	learn: 0.0000247	total: 11.2s	remaining: 41.8s
# 212:	learn: 0.0000245	total: 11.3s	remaining: 41.7s
# 213:	learn: 0.0000245	total: 11.3s	remaining: 41.5s
# 214:	learn: 0.0000244	total: 11.4s	remaining: 41.5s
# 215:	learn: 0.0000242	total: 11.4s	remaining: 41.3s
# 216:	learn: 0.0000240	total: 11.4s	remaining: 41.3s
# 217:	learn: 0.0000237	total: 11.5s	remaining: 41.2s
# 218:	learn: 0.0000235	total: 11.5s	remaining: 41.1s
# 219:	learn: 0.0000233	total: 11.6s	remaining: 41s
# 220:	learn: 0.0000231	total: 11.6s	remaining: 41s
# 221:	learn: 0.0000229	total: 11.7s	remaining: 41s
# 222:	learn: 0.0000227	total: 11.8s	remaining: 41s
# 223:	learn: 0.0000224	total: 11.8s	remaining: 41s
# 224:	learn: 0.0000222	total: 11.9s	remaining: 41s
# 225:	learn: 0.0000220	total: 12s	remaining: 41s
# 226:	learn: 0.0000217	total: 12s	remaining: 41s
# 227:	learn: 0.0000216	total: 12.1s	remaining: 40.9s
# 228:	learn: 0.0000213	total: 12.1s	remaining: 40.8s
# 229:	learn: 0.0000213	total: 12.2s	remaining: 40.8s
# 230:	learn: 0.0000212	total: 12.2s	remaining: 40.7s
# 231:	learn: 0.0000212	total: 12.3s	remaining: 40.6s
# 232:	learn: 0.0000210	total: 12.3s	remaining: 40.5s
# 233:	learn: 0.0000210	total: 12.4s	remaining: 40.4s
# 234:	learn: 0.0000209	total: 12.4s	remaining: 40.4s
# 235:	learn: 0.0000208	total: 12.5s	remaining: 40.3s
# 236:	learn: 0.0000206	total: 12.5s	remaining: 40.2s
# 237:	learn: 0.0000205	total: 12.5s	remaining: 40.2s
# 238:	learn: 0.0000202	total: 12.6s	remaining: 40.1s
# 239:	learn: 0.0000200	total: 12.6s	remaining: 40s
# 240:	learn: 0.0000198	total: 12.7s	remaining: 39.9s
# 241:	learn: 0.0000196	total: 12.7s	remaining: 39.8s
# 242:	learn: 0.0000194	total: 12.8s	remaining: 39.7s
# 243:	learn: 0.0000192	total: 12.8s	remaining: 39.7s
# 244:	learn: 0.0000191	total: 12.8s	remaining: 39.6s
# 245:	learn: 0.0000189	total: 12.9s	remaining: 39.5s
# 246:	learn: 0.0000188	total: 12.9s	remaining: 39.4s
# 247:	learn: 0.0000186	total: 13s	remaining: 39.3s
# 248:	learn: 0.0000184	total: 13s	remaining: 39.2s
# 249:	learn: 0.0000183	total: 13.1s	remaining: 39.2s
# 250:	learn: 0.0000181	total: 13.1s	remaining: 39.1s
# 251:	learn: 0.0000180	total: 13.1s	remaining: 39s
# 252:	learn: 0.0000180	total: 13.2s	remaining: 38.9s
# 253:	learn: 0.0000179	total: 13.2s	remaining: 38.8s
# 254:	learn: 0.0000178	total: 13.3s	remaining: 38.7s
# 255:	learn: 0.0000177	total: 13.3s	remaining: 38.7s
# 256:	learn: 0.0000177	total: 13.3s	remaining: 38.6s
# 257:	learn: 0.0000177	total: 13.4s	remaining: 38.5s
# 258:	learn: 0.0000176	total: 13.4s	remaining: 38.4s
# 259:	learn: 0.0000176	total: 13.4s	remaining: 38.3s
# 260:	learn: 0.0000174	total: 13.5s	remaining: 38.2s
# 261:	learn: 0.0000173	total: 13.5s	remaining: 38.1s
# 262:	learn: 0.0000172	total: 13.6s	remaining: 38s
# 263:	learn: 0.0000171	total: 13.6s	remaining: 38s
# 264:	learn: 0.0000170	total: 13.7s	remaining: 37.9s
# 265:	learn: 0.0000169	total: 13.7s	remaining: 37.8s
# 266:	learn: 0.0000168	total: 13.8s	remaining: 37.8s
# 267:	learn: 0.0000167	total: 13.8s	remaining: 37.7s
# 268:	learn: 0.0000167	total: 13.8s	remaining: 37.6s
# 269:	learn: 0.0000167	total: 13.9s	remaining: 37.5s
# 270:	learn: 0.0000165	total: 13.9s	remaining: 37.5s
# 271:	learn: 0.0000164	total: 14s	remaining: 37.4s
# 272:	learn: 0.0000163	total: 14s	remaining: 37.4s
# 273:	learn: 0.0000162	total: 14.1s	remaining: 37.3s
# 274:	learn: 0.0000161	total: 14.1s	remaining: 37.3s
# 275:	learn: 0.0000161	total: 14.2s	remaining: 37.2s
# 276:	learn: 0.0000161	total: 14.3s	remaining: 37.2s
# 277:	learn: 0.0000159	total: 14.3s	remaining: 37.1s
# 278:	learn: 0.0000159	total: 14.4s	remaining: 37.1s
# 279:	learn: 0.0000157	total: 14.4s	remaining: 37s
# 280:	learn: 0.0000157	total: 14.4s	remaining: 37s
# 281:	learn: 0.0000156	total: 14.5s	remaining: 36.9s
# 282:	learn: 0.0000156	total: 14.5s	remaining: 36.8s
# 283:	learn: 0.0000155	total: 14.6s	remaining: 36.7s
# 284:	learn: 0.0000155	total: 14.6s	remaining: 36.7s
# 285:	learn: 0.0000154	total: 14.7s	remaining: 36.6s
# 286:	learn: 0.0000153	total: 14.7s	remaining: 36.6s
# 287:	learn: 0.0000153	total: 14.8s	remaining: 36.5s
# 288:	learn: 0.0000153	total: 14.8s	remaining: 36.5s
# 289:	learn: 0.0000153	total: 14.9s	remaining: 36.4s
# 290:	learn: 0.0000152	total: 14.9s	remaining: 36.3s
# 291:	learn: 0.0000151	total: 15s	remaining: 36.3s
# 292:	learn: 0.0000150	total: 15s	remaining: 36.2s
# 293:	learn: 0.0000149	total: 15s	remaining: 36.1s
# 294:	learn: 0.0000148	total: 15.1s	remaining: 36.1s
# 295:	learn: 0.0000148	total: 15.1s	remaining: 36s
# 296:	learn: 0.0000147	total: 15.2s	remaining: 35.9s
# 297:	learn: 0.0000146	total: 15.2s	remaining: 35.9s
# 298:	learn: 0.0000145	total: 15.3s	remaining: 35.8s
# 299:	learn: 0.0000145	total: 15.3s	remaining: 35.7s
# 300:	learn: 0.0000145	total: 15.4s	remaining: 35.7s
# 301:	learn: 0.0000144	total: 15.4s	remaining: 35.6s
# 302:	learn: 0.0000144	total: 15.4s	remaining: 35.5s
# 303:	learn: 0.0000143	total: 15.5s	remaining: 35.4s
# 304:	learn: 0.0000143	total: 15.5s	remaining: 35.4s
# 305:	learn: 0.0000142	total: 15.6s	remaining: 35.3s
# 306:	learn: 0.0000141	total: 15.6s	remaining: 35.2s
# 307:	learn: 0.0000140	total: 15.6s	remaining: 35.2s
# 308:	learn: 0.0000139	total: 15.7s	remaining: 35.1s
# 309:	learn: 0.0000139	total: 15.7s	remaining: 35s
# 310:	learn: 0.0000139	total: 15.8s	remaining: 34.9s
# 311:	learn: 0.0000139	total: 15.8s	remaining: 34.8s
# 312:	learn: 0.0000138	total: 15.8s	remaining: 34.8s
# 313:	learn: 0.0000138	total: 15.9s	remaining: 34.7s
# 314:	learn: 0.0000138	total: 15.9s	remaining: 34.6s
# 315:	learn: 0.0000138	total: 16s	remaining: 34.6s
# 316:	learn: 0.0000137	total: 16s	remaining: 34.5s
# 317:	learn: 0.0000137	total: 16.1s	remaining: 34.4s
# 318:	learn: 0.0000136	total: 16.1s	remaining: 34.4s
# 319:	learn: 0.0000135	total: 16.2s	remaining: 34.3s
# 320:	learn: 0.0000135	total: 16.2s	remaining: 34.3s
# 321:	learn: 0.0000134	total: 16.3s	remaining: 34.2s
# 322:	learn: 0.0000133	total: 16.3s	remaining: 34.2s
# 323:	learn: 0.0000133	total: 16.3s	remaining: 34.1s
# 324:	learn: 0.0000132	total: 16.4s	remaining: 34s
# 325:	learn: 0.0000132	total: 16.4s	remaining: 33.9s
# 326:	learn: 0.0000132	total: 16.5s	remaining: 33.9s
# 327:	learn: 0.0000131	total: 16.5s	remaining: 33.8s
# 328:	learn: 0.0000130	total: 16.5s	remaining: 33.7s
# 329:	learn: 0.0000129	total: 16.6s	remaining: 33.7s
# 330:	learn: 0.0000129	total: 16.6s	remaining: 33.6s
# 331:	learn: 0.0000128	total: 16.7s	remaining: 33.6s
# 332:	learn: 0.0000127	total: 16.7s	remaining: 33.5s
# 333:	learn: 0.0000127	total: 16.8s	remaining: 33.4s
# 334:	learn: 0.0000126	total: 16.8s	remaining: 33.4s
# 335:	learn: 0.0000125	total: 16.9s	remaining: 33.3s
# 336:	learn: 0.0000125	total: 16.9s	remaining: 33.3s
# 337:	learn: 0.0000124	total: 16.9s	remaining: 33.2s
# 338:	learn: 0.0000123	total: 17s	remaining: 33.1s
# 339:	learn: 0.0000123	total: 17s	remaining: 33.1s
# 340:	learn: 0.0000123	total: 17.1s	remaining: 33s
# 341:	learn: 0.0000122	total: 17.1s	remaining: 32.9s
# 342:	learn: 0.0000122	total: 17.2s	remaining: 32.9s
# 343:	learn: 0.0000122	total: 17.2s	remaining: 32.8s
# 344:	learn: 0.0000122	total: 17.3s	remaining: 32.8s
# 345:	learn: 0.0000122	total: 17.3s	remaining: 32.7s
# 346:	learn: 0.0000121	total: 17.3s	remaining: 32.6s
# 347:	learn: 0.0000120	total: 17.4s	remaining: 32.6s
# 348:	learn: 0.0000120	total: 17.4s	remaining: 32.5s
# 349:	learn: 0.0000120	total: 17.5s	remaining: 32.4s
# 350:	learn: 0.0000120	total: 17.5s	remaining: 32.4s
# 351:	learn: 0.0000119	total: 17.6s	remaining: 32.3s
# 352:	learn: 0.0000119	total: 17.6s	remaining: 32.3s
# 353:	learn: 0.0000119	total: 17.7s	remaining: 32.2s
# 354:	learn: 0.0000118	total: 17.7s	remaining: 32.2s
# 355:	learn: 0.0000118	total: 17.7s	remaining: 32.1s
# 356:	learn: 0.0000118	total: 17.8s	remaining: 32s
# 357:	learn: 0.0000118	total: 17.8s	remaining: 31.9s
# 358:	learn: 0.0000117	total: 17.9s	remaining: 31.9s
# 359:	learn: 0.0000117	total: 17.9s	remaining: 31.8s
# 360:	learn: 0.0000116	total: 17.9s	remaining: 31.7s
# 361:	learn: 0.0000116	total: 18s	remaining: 31.7s
# 362:	learn: 0.0000116	total: 18s	remaining: 31.6s
# 363:	learn: 0.0000115	total: 18s	remaining: 31.5s
# 364:	learn: 0.0000115	total: 18.1s	remaining: 31.4s
# 365:	learn: 0.0000114	total: 18.1s	remaining: 31.4s
# 366:	learn: 0.0000114	total: 18.2s	remaining: 31.3s
# 367:	learn: 0.0000114	total: 18.2s	remaining: 31.3s
# 368:	learn: 0.0000113	total: 18.3s	remaining: 31.2s
# 369:	learn: 0.0000113	total: 18.3s	remaining: 31.1s
# 370:	learn: 0.0000113	total: 18.3s	remaining: 31.1s
# 371:	learn: 0.0000113	total: 18.4s	remaining: 31s
# 372:	learn: 0.0000112	total: 18.4s	remaining: 30.9s
# 373:	learn: 0.0000111	total: 18.4s	remaining: 30.9s
# 374:	learn: 0.0000111	total: 18.5s	remaining: 30.8s
# 375:	learn: 0.0000111	total: 18.5s	remaining: 30.7s
# 376:	learn: 0.0000111	total: 18.6s	remaining: 30.7s
# 377:	learn: 0.0000110	total: 18.6s	remaining: 30.6s
# 378:	learn: 0.0000110	total: 18.6s	remaining: 30.5s
# 379:	learn: 0.0000109	total: 18.7s	remaining: 30.5s
# 380:	learn: 0.0000109	total: 18.7s	remaining: 30.4s
# 381:	learn: 0.0000109	total: 18.8s	remaining: 30.4s
# 382:	learn: 0.0000109	total: 18.8s	remaining: 30.3s
# 383:	learn: 0.0000108	total: 18.9s	remaining: 30.2s
# 384:	learn: 0.0000108	total: 18.9s	remaining: 30.2s
# 385:	learn: 0.0000107	total: 18.9s	remaining: 30.1s
# 386:	learn: 0.0000107	total: 19s	remaining: 30.1s
# 387:	learn: 0.0000107	total: 19s	remaining: 30s
# 388:	learn: 0.0000106	total: 19.1s	remaining: 30s
# 389:	learn: 0.0000106	total: 19.1s	remaining: 29.9s
# 390:	learn: 0.0000106	total: 19.2s	remaining: 29.8s
# 391:	learn: 0.0000106	total: 19.2s	remaining: 29.8s
# 392:	learn: 0.0000105	total: 19.2s	remaining: 29.7s
# 393:	learn: 0.0000105	total: 19.3s	remaining: 29.7s
# 394:	learn: 0.0000105	total: 19.3s	remaining: 29.6s
# 395:	learn: 0.0000105	total: 19.4s	remaining: 29.6s
# 396:	learn: 0.0000105	total: 19.4s	remaining: 29.5s
# 397:	learn: 0.0000104	total: 19.5s	remaining: 29.4s
# 398:	learn: 0.0000104	total: 19.5s	remaining: 29.4s
# 399:	learn: 0.0000103	total: 19.6s	remaining: 29.3s
# 400:	learn: 0.0000103	total: 19.6s	remaining: 29.3s
# 401:	learn: 0.0000102	total: 19.6s	remaining: 29.2s
# 402:	learn: 0.0000102	total: 19.7s	remaining: 29.1s
# 403:	learn: 0.0000101	total: 19.7s	remaining: 29.1s
# 404:	learn: 0.0000101	total: 19.8s	remaining: 29s
# 405:	learn: 0.0000101	total: 19.8s	remaining: 29s
# 406:	learn: 0.0000101	total: 19.9s	remaining: 29s
# 407:	learn: 0.0000100	total: 19.9s	remaining: 28.9s
# 408:	learn: 0.0000100	total: 20s	remaining: 28.8s
# 409:	learn: 0.0000100	total: 20s	remaining: 28.8s
# 410:	learn: 0.0000099	total: 20.1s	remaining: 28.7s
# 411:	learn: 0.0000099	total: 20.1s	remaining: 28.7s
# 412:	learn: 0.0000099	total: 20.1s	remaining: 28.6s
# 413:	learn: 0.0000099	total: 20.2s	remaining: 28.6s
# 414:	learn: 0.0000098	total: 20.2s	remaining: 28.5s
# 415:	learn: 0.0000098	total: 20.3s	remaining: 28.5s
# 416:	learn: 0.0000098	total: 20.3s	remaining: 28.4s
# 417:	learn: 0.0000098	total: 20.4s	remaining: 28.3s
# 418:	learn: 0.0000097	total: 20.4s	remaining: 28.3s
# 419:	learn: 0.0000097	total: 20.4s	remaining: 28.2s
# 420:	learn: 0.0000096	total: 20.5s	remaining: 28.2s
# 421:	learn: 0.0000096	total: 20.5s	remaining: 28.1s
# 422:	learn: 0.0000096	total: 20.6s	remaining: 28.1s
# 423:	learn: 0.0000095	total: 20.6s	remaining: 28s
# 424:	learn: 0.0000095	total: 20.6s	remaining: 27.9s
# 425:	learn: 0.0000095	total: 20.7s	remaining: 27.9s
# 426:	learn: 0.0000095	total: 20.7s	remaining: 27.8s
# 427:	learn: 0.0000095	total: 20.8s	remaining: 27.8s
# 428:	learn: 0.0000095	total: 20.8s	remaining: 27.7s
# 429:	learn: 0.0000095	total: 20.8s	remaining: 27.6s
# 430:	learn: 0.0000094	total: 20.9s	remaining: 27.6s
# 431:	learn: 0.0000094	total: 20.9s	remaining: 27.5s
# 432:	learn: 0.0000094	total: 21s	remaining: 27.5s
# 433:	learn: 0.0000093	total: 21s	remaining: 27.4s
# 434:	learn: 0.0000093	total: 21.1s	remaining: 27.4s
# 435:	learn: 0.0000093	total: 21.1s	remaining: 27.3s
# 436:	learn: 0.0000092	total: 21.2s	remaining: 27.3s
# 437:	learn: 0.0000092	total: 21.2s	remaining: 27.2s
# 438:	learn: 0.0000092	total: 21.2s	remaining: 27.1s
# 439:	learn: 0.0000092	total: 21.3s	remaining: 27.1s
# 440:	learn: 0.0000092	total: 21.3s	remaining: 27s
# 441:	learn: 0.0000092	total: 21.4s	remaining: 27s
# 442:	learn: 0.0000091	total: 21.4s	remaining: 26.9s
# 443:	learn: 0.0000091	total: 21.5s	remaining: 26.9s
# 444:	learn: 0.0000091	total: 21.5s	remaining: 26.8s
# 445:	learn: 0.0000090	total: 21.5s	remaining: 26.8s
# 446:	learn: 0.0000090	total: 21.6s	remaining: 26.7s
# 447:	learn: 0.0000090	total: 21.6s	remaining: 26.7s
# 448:	learn: 0.0000089	total: 21.7s	remaining: 26.6s
# 449:	learn: 0.0000089	total: 21.7s	remaining: 26.5s
# 450:	learn: 0.0000089	total: 21.7s	remaining: 26.5s
# 451:	learn: 0.0000089	total: 21.8s	remaining: 26.4s
# 452:	learn: 0.0000088	total: 21.8s	remaining: 26.4s
# 453:	learn: 0.0000088	total: 21.9s	remaining: 26.3s
# 454:	learn: 0.0000088	total: 21.9s	remaining: 26.2s
# 455:	learn: 0.0000087	total: 21.9s	remaining: 26.2s
# 456:	learn: 0.0000087	total: 22s	remaining: 26.1s
# 457:	learn: 0.0000087	total: 22s	remaining: 26.1s
# 458:	learn: 0.0000087	total: 22.1s	remaining: 26s
# 459:	learn: 0.0000087	total: 22.1s	remaining: 26s
# 460:	learn: 0.0000087	total: 22.2s	remaining: 25.9s
# 461:	learn: 0.0000087	total: 22.2s	remaining: 25.9s
# 462:	learn: 0.0000086	total: 22.3s	remaining: 25.8s
# 463:	learn: 0.0000086	total: 22.3s	remaining: 25.8s
# 464:	learn: 0.0000086	total: 22.4s	remaining: 25.7s
# 465:	learn: 0.0000086	total: 22.4s	remaining: 25.7s
# 466:	learn: 0.0000086	total: 22.4s	remaining: 25.6s
# 467:	learn: 0.0000086	total: 22.5s	remaining: 25.6s
# 468:	learn: 0.0000086	total: 22.5s	remaining: 25.5s
# 469:	learn: 0.0000086	total: 22.6s	remaining: 25.5s
# 470:	learn: 0.0000085	total: 22.6s	remaining: 25.4s
# 471:	learn: 0.0000085	total: 22.6s	remaining: 25.3s
# 472:	learn: 0.0000085	total: 22.7s	remaining: 25.3s
# 473:	learn: 0.0000085	total: 22.7s	remaining: 25.2s
# 474:	learn: 0.0000085	total: 22.8s	remaining: 25.2s
# 475:	learn: 0.0000085	total: 22.8s	remaining: 25.1s
# 476:	learn: 0.0000085	total: 22.9s	remaining: 25.1s
# 477:	learn: 0.0000084	total: 22.9s	remaining: 25s
# 478:	learn: 0.0000084	total: 23s	remaining: 25s
# 479:	learn: 0.0000084	total: 23s	remaining: 24.9s
# 480:	learn: 0.0000084	total: 23s	remaining: 24.9s
# 481:	learn: 0.0000084	total: 23.1s	remaining: 24.8s
# 482:	learn: 0.0000084	total: 23.1s	remaining: 24.7s
# 483:	learn: 0.0000083	total: 23.2s	remaining: 24.7s
# 484:	learn: 0.0000083	total: 23.2s	remaining: 24.6s
# 485:	learn: 0.0000083	total: 23.3s	remaining: 24.6s
# 486:	learn: 0.0000083	total: 23.3s	remaining: 24.5s
# 487:	learn: 0.0000083	total: 23.3s	remaining: 24.5s
# 488:	learn: 0.0000083	total: 23.4s	remaining: 24.4s
# 489:	learn: 0.0000082	total: 23.4s	remaining: 24.4s
# 490:	learn: 0.0000082	total: 23.5s	remaining: 24.3s
# 491:	learn: 0.0000082	total: 23.5s	remaining: 24.3s
# 492:	learn: 0.0000082	total: 23.5s	remaining: 24.2s
# 493:	learn: 0.0000082	total: 23.6s	remaining: 24.2s
# 494:	learn: 0.0000082	total: 23.6s	remaining: 24.1s
# 495:	learn: 0.0000081	total: 23.7s	remaining: 24s
# 496:	learn: 0.0000081	total: 23.7s	remaining: 24s
# 497:	learn: 0.0000081	total: 23.8s	remaining: 23.9s
# 498:	learn: 0.0000081	total: 23.8s	remaining: 23.9s
# 499:	learn: 0.0000080	total: 23.8s	remaining: 23.8s
# 500:	learn: 0.0000080	total: 23.9s	remaining: 23.8s
# 501:	learn: 0.0000080	total: 23.9s	remaining: 23.7s
# 502:	learn: 0.0000080	total: 24s	remaining: 23.7s
# 503:	learn: 0.0000080	total: 24s	remaining: 23.6s
# 504:	learn: 0.0000080	total: 24.1s	remaining: 23.6s
# 505:	learn: 0.0000080	total: 24.1s	remaining: 23.5s
# 506:	learn: 0.0000080	total: 24.2s	remaining: 23.5s
# 507:	learn: 0.0000080	total: 24.2s	remaining: 23.4s
# 508:	learn: 0.0000079	total: 24.2s	remaining: 23.4s
# 509:	learn: 0.0000079	total: 24.3s	remaining: 23.3s
# 510:	learn: 0.0000079	total: 24.3s	remaining: 23.3s
# 511:	learn: 0.0000079	total: 24.4s	remaining: 23.2s
# 512:	learn: 0.0000079	total: 24.4s	remaining: 23.2s
# 513:	learn: 0.0000079	total: 24.4s	remaining: 23.1s
# 514:	learn: 0.0000079	total: 24.5s	remaining: 23.1s
# 515:	learn: 0.0000079	total: 24.5s	remaining: 23s
# 516:	learn: 0.0000079	total: 24.6s	remaining: 23s
# 517:	learn: 0.0000079	total: 24.6s	remaining: 22.9s
# 518:	learn: 0.0000078	total: 24.7s	remaining: 22.9s
# 519:	learn: 0.0000078	total: 24.7s	remaining: 22.8s
# 520:	learn: 0.0000078	total: 24.8s	remaining: 22.8s
# 521:	learn: 0.0000078	total: 24.8s	remaining: 22.7s
# 522:	learn: 0.0000077	total: 24.8s	remaining: 22.7s
# 523:	learn: 0.0000077	total: 24.9s	remaining: 22.6s
# 524:	learn: 0.0000077	total: 24.9s	remaining: 22.6s
# 525:	learn: 0.0000077	total: 25s	remaining: 22.5s
# 526:	learn: 0.0000077	total: 25.1s	remaining: 22.5s
# 527:	learn: 0.0000077	total: 25.1s	remaining: 22.4s
# 528:	learn: 0.0000077	total: 25.1s	remaining: 22.4s
# 529:	learn: 0.0000077	total: 25.2s	remaining: 22.3s
# 530:	learn: 0.0000076	total: 25.2s	remaining: 22.3s
# 531:	learn: 0.0000076	total: 25.3s	remaining: 22.3s
# 532:	learn: 0.0000076	total: 25.4s	remaining: 22.2s
# 533:	learn: 0.0000076	total: 25.4s	remaining: 22.2s
# 534:	learn: 0.0000076	total: 25.4s	remaining: 22.1s
# 535:	learn: 0.0000075	total: 25.5s	remaining: 22.1s
# 536:	learn: 0.0000075	total: 25.5s	remaining: 22s
# 537:	learn: 0.0000075	total: 25.6s	remaining: 22s
# 538:	learn: 0.0000075	total: 25.6s	remaining: 21.9s
# 539:	learn: 0.0000075	total: 25.7s	remaining: 21.9s
# 540:	learn: 0.0000075	total: 25.7s	remaining: 21.8s
# 541:	learn: 0.0000075	total: 25.7s	remaining: 21.8s
# 542:	learn: 0.0000075	total: 25.8s	remaining: 21.7s
# 543:	learn: 0.0000074	total: 25.8s	remaining: 21.7s
# 544:	learn: 0.0000074	total: 25.9s	remaining: 21.6s
# 545:	learn: 0.0000074	total: 25.9s	remaining: 21.6s
# 546:	learn: 0.0000074	total: 26s	remaining: 21.5s
# 547:	learn: 0.0000074	total: 26s	remaining: 21.5s
# 548:	learn: 0.0000073	total: 26.1s	remaining: 21.4s
# 549:	learn: 0.0000073	total: 26.1s	remaining: 21.4s
# 550:	learn: 0.0000073	total: 26.2s	remaining: 21.3s
# 551:	learn: 0.0000073	total: 26.2s	remaining: 21.3s
# 552:	learn: 0.0000073	total: 26.3s	remaining: 21.2s
# 553:	learn: 0.0000073	total: 26.3s	remaining: 21.2s
# 554:	learn: 0.0000073	total: 26.3s	remaining: 21.1s
# 555:	learn: 0.0000072	total: 26.4s	remaining: 21.1s
# 556:	learn: 0.0000072	total: 26.4s	remaining: 21s
# 557:	learn: 0.0000072	total: 26.5s	remaining: 21s
# 558:	learn: 0.0000072	total: 26.5s	remaining: 20.9s
# 559:	learn: 0.0000072	total: 26.6s	remaining: 20.9s
# 560:	learn: 0.0000072	total: 26.6s	remaining: 20.8s
# 561:	learn: 0.0000072	total: 26.7s	remaining: 20.8s
# 562:	learn: 0.0000072	total: 26.8s	remaining: 20.8s
# 563:	learn: 0.0000072	total: 26.9s	remaining: 20.8s
# 564:	learn: 0.0000072	total: 27s	remaining: 20.8s
# 565:	learn: 0.0000071	total: 27.1s	remaining: 20.7s
# 566:	learn: 0.0000071	total: 27.1s	remaining: 20.7s
# 567:	learn: 0.0000071	total: 27.2s	remaining: 20.7s
# 568:	learn: 0.0000071	total: 27.3s	remaining: 20.6s
# 569:	learn: 0.0000071	total: 27.3s	remaining: 20.6s
# 570:	learn: 0.0000071	total: 27.4s	remaining: 20.6s
# 571:	learn: 0.0000071	total: 27.5s	remaining: 20.5s
# 572:	learn: 0.0000071	total: 27.6s	remaining: 20.5s
# 573:	learn: 0.0000071	total: 27.7s	remaining: 20.5s
# 574:	learn: 0.0000071	total: 27.7s	remaining: 20.5s
# 575:	learn: 0.0000071	total: 27.8s	remaining: 20.4s
# 576:	learn: 0.0000070	total: 27.8s	remaining: 20.4s
# 577:	learn: 0.0000070	total: 27.9s	remaining: 20.4s
# 578:	learn: 0.0000070	total: 28s	remaining: 20.3s
# 579:	learn: 0.0000070	total: 28s	remaining: 20.3s
# 580:	learn: 0.0000070	total: 28.1s	remaining: 20.3s
# 581:	learn: 0.0000070	total: 28.2s	remaining: 20.2s
# 582:	learn: 0.0000069	total: 28.2s	remaining: 20.2s
# 583:	learn: 0.0000069	total: 28.3s	remaining: 20.2s
# 584:	learn: 0.0000069	total: 28.4s	remaining: 20.1s
# 585:	learn: 0.0000069	total: 28.4s	remaining: 20.1s
# 586:	learn: 0.0000069	total: 28.5s	remaining: 20s
# 587:	learn: 0.0000069	total: 28.5s	remaining: 20s
# 588:	learn: 0.0000068	total: 28.6s	remaining: 19.9s
# 589:	learn: 0.0000068	total: 28.6s	remaining: 19.9s
# 590:	learn: 0.0000068	total: 28.7s	remaining: 19.8s
# 591:	learn: 0.0000068	total: 28.7s	remaining: 19.8s
# 592:	learn: 0.0000068	total: 28.8s	remaining: 19.8s
# 593:	learn: 0.0000068	total: 28.8s	remaining: 19.7s
# 594:	learn: 0.0000067	total: 28.9s	remaining: 19.6s
# 595:	learn: 0.0000067	total: 28.9s	remaining: 19.6s
# 596:	learn: 0.0000067	total: 29s	remaining: 19.5s
# 597:	learn: 0.0000067	total: 29s	remaining: 19.5s
# 598:	learn: 0.0000067	total: 29s	remaining: 19.4s
# 599:	learn: 0.0000067	total: 29.1s	remaining: 19.4s
# 600:	learn: 0.0000067	total: 29.1s	remaining: 19.3s
# 601:	learn: 0.0000067	total: 29.2s	remaining: 19.3s
# 602:	learn: 0.0000067	total: 29.2s	remaining: 19.2s
# 603:	learn: 0.0000067	total: 29.3s	remaining: 19.2s
# 604:	learn: 0.0000066	total: 29.3s	remaining: 19.1s
# 605:	learn: 0.0000066	total: 29.4s	remaining: 19.1s
# 606:	learn: 0.0000066	total: 29.4s	remaining: 19.1s
# 607:	learn: 0.0000066	total: 29.5s	remaining: 19s
# 608:	learn: 0.0000066	total: 29.5s	remaining: 18.9s
# 609:	learn: 0.0000066	total: 29.6s	remaining: 18.9s
# 610:	learn: 0.0000066	total: 29.6s	remaining: 18.8s
# 611:	learn: 0.0000066	total: 29.7s	remaining: 18.8s
# 612:	learn: 0.0000066	total: 29.7s	remaining: 18.7s
# 613:	learn: 0.0000066	total: 29.7s	remaining: 18.7s
# 614:	learn: 0.0000066	total: 29.8s	remaining: 18.7s
# 615:	learn: 0.0000065	total: 29.8s	remaining: 18.6s
# 616:	learn: 0.0000065	total: 29.9s	remaining: 18.6s
# 617:	learn: 0.0000065	total: 29.9s	remaining: 18.5s
# 618:	learn: 0.0000065	total: 30s	remaining: 18.4s
# 619:	learn: 0.0000065	total: 30s	remaining: 18.4s
# 620:	learn: 0.0000065	total: 30.1s	remaining: 18.3s
# 621:	learn: 0.0000065	total: 30.1s	remaining: 18.3s
# 622:	learn: 0.0000065	total: 30.1s	remaining: 18.2s
# 623:	learn: 0.0000065	total: 30.2s	remaining: 18.2s
# 624:	learn: 0.0000064	total: 30.2s	remaining: 18.1s
# 625:	learn: 0.0000064	total: 30.3s	remaining: 18.1s
# 626:	learn: 0.0000064	total: 30.3s	remaining: 18s
# 627:	learn: 0.0000064	total: 30.4s	remaining: 18s
# 628:	learn: 0.0000064	total: 30.4s	remaining: 17.9s
# 629:	learn: 0.0000064	total: 30.5s	remaining: 17.9s
# 630:	learn: 0.0000064	total: 30.5s	remaining: 17.9s
# 631:	learn: 0.0000064	total: 30.6s	remaining: 17.8s
# 632:	learn: 0.0000064	total: 30.6s	remaining: 17.8s
# 633:	learn: 0.0000064	total: 30.7s	remaining: 17.7s
# 634:	learn: 0.0000064	total: 30.8s	remaining: 17.7s
# 635:	learn: 0.0000064	total: 30.9s	remaining: 17.7s
# 636:	learn: 0.0000063	total: 30.9s	remaining: 17.6s
# 637:	learn: 0.0000063	total: 31s	remaining: 17.6s
# 638:	learn: 0.0000063	total: 31.1s	remaining: 17.5s
# 639:	learn: 0.0000063	total: 31.1s	remaining: 17.5s
# 640:	learn: 0.0000063	total: 31.2s	remaining: 17.5s
# 641:	learn: 0.0000063	total: 31.3s	remaining: 17.4s
# 642:	learn: 0.0000063	total: 31.3s	remaining: 17.4s
# 643:	learn: 0.0000062	total: 31.4s	remaining: 17.4s
# 644:	learn: 0.0000062	total: 31.4s	remaining: 17.3s
# 645:	learn: 0.0000062	total: 31.5s	remaining: 17.2s
# 646:	learn: 0.0000062	total: 31.5s	remaining: 17.2s
# 647:	learn: 0.0000062	total: 31.6s	remaining: 17.1s
# 648:	learn: 0.0000062	total: 31.6s	remaining: 17.1s
# 649:	learn: 0.0000062	total: 31.6s	remaining: 17s
# 650:	learn: 0.0000062	total: 31.7s	remaining: 17s
# 651:	learn: 0.0000062	total: 31.7s	remaining: 16.9s
# 652:	learn: 0.0000062	total: 31.8s	remaining: 16.9s
# 653:	learn: 0.0000061	total: 31.8s	remaining: 16.8s
# 654:	learn: 0.0000061	total: 31.9s	remaining: 16.8s
# 655:	learn: 0.0000061	total: 31.9s	remaining: 16.7s
# 656:	learn: 0.0000061	total: 32s	remaining: 16.7s
# 657:	learn: 0.0000061	total: 32s	remaining: 16.6s
# 658:	learn: 0.0000061	total: 32.1s	remaining: 16.6s
# 659:	learn: 0.0000061	total: 32.2s	remaining: 16.6s
# 660:	learn: 0.0000060	total: 32.2s	remaining: 16.5s
# 661:	learn: 0.0000060	total: 32.3s	remaining: 16.5s
# 662:	learn: 0.0000060	total: 32.4s	remaining: 16.5s
# 663:	learn: 0.0000060	total: 32.4s	remaining: 16.4s
# 664:	learn: 0.0000060	total: 32.5s	remaining: 16.4s
# 665:	learn: 0.0000060	total: 32.5s	remaining: 16.3s
# 666:	learn: 0.0000060	total: 32.6s	remaining: 16.3s
# 667:	learn: 0.0000060	total: 32.6s	remaining: 16.2s
# 668:	learn: 0.0000060	total: 32.7s	remaining: 16.2s
# 669:	learn: 0.0000060	total: 32.7s	remaining: 16.1s
# 670:	learn: 0.0000060	total: 32.8s	remaining: 16.1s
# 671:	learn: 0.0000060	total: 32.8s	remaining: 16s
# 672:	learn: 0.0000059	total: 32.9s	remaining: 16s
# 673:	learn: 0.0000059	total: 33s	remaining: 15.9s
# 674:	learn: 0.0000059	total: 33s	remaining: 15.9s
# 675:	learn: 0.0000059	total: 33.1s	remaining: 15.8s
# 676:	learn: 0.0000059	total: 33.1s	remaining: 15.8s
# 677:	learn: 0.0000059	total: 33.1s	remaining: 15.7s
# 678:	learn: 0.0000059	total: 33.2s	remaining: 15.7s
# 679:	learn: 0.0000059	total: 33.2s	remaining: 15.6s
# 680:	learn: 0.0000058	total: 33.3s	remaining: 15.6s
# 681:	learn: 0.0000058	total: 33.3s	remaining: 15.5s
# 682:	learn: 0.0000058	total: 33.4s	remaining: 15.5s
# 683:	learn: 0.0000058	total: 33.4s	remaining: 15.4s
# 684:	learn: 0.0000058	total: 33.4s	remaining: 15.4s
# 685:	learn: 0.0000058	total: 33.5s	remaining: 15.3s
# 686:	learn: 0.0000058	total: 33.5s	remaining: 15.3s
# 687:	learn: 0.0000058	total: 33.6s	remaining: 15.2s
# 688:	learn: 0.0000058	total: 33.6s	remaining: 15.2s
# 689:	learn: 0.0000057	total: 33.6s	remaining: 15.1s
# 690:	learn: 0.0000057	total: 33.7s	remaining: 15.1s
# 691:	learn: 0.0000057	total: 33.7s	remaining: 15s
# 692:	learn: 0.0000057	total: 33.8s	remaining: 15s
# 693:	learn: 0.0000057	total: 33.8s	remaining: 14.9s
# 694:	learn: 0.0000057	total: 33.9s	remaining: 14.9s
# 695:	learn: 0.0000057	total: 33.9s	remaining: 14.8s
# 696:	learn: 0.0000057	total: 33.9s	remaining: 14.8s
# 697:	learn: 0.0000057	total: 34s	remaining: 14.7s
# 698:	learn: 0.0000057	total: 34s	remaining: 14.7s
# 699:	learn: 0.0000057	total: 34.1s	remaining: 14.6s
# 700:	learn: 0.0000056	total: 34.1s	remaining: 14.6s
# 701:	learn: 0.0000056	total: 34.2s	remaining: 14.5s
# 702:	learn: 0.0000056	total: 34.2s	remaining: 14.5s
# 703:	learn: 0.0000056	total: 34.2s	remaining: 14.4s
# 704:	learn: 0.0000056	total: 34.3s	remaining: 14.3s
# 705:	learn: 0.0000056	total: 34.3s	remaining: 14.3s
# 706:	learn: 0.0000056	total: 34.4s	remaining: 14.2s
# 707:	learn: 0.0000056	total: 34.4s	remaining: 14.2s
# 708:	learn: 0.0000056	total: 34.4s	remaining: 14.1s
# 709:	learn: 0.0000056	total: 34.5s	remaining: 14.1s
# 710:	learn: 0.0000055	total: 34.6s	remaining: 14s
# 711:	learn: 0.0000055	total: 34.6s	remaining: 14s
# 712:	learn: 0.0000055	total: 34.6s	remaining: 13.9s
# 713:	learn: 0.0000055	total: 34.7s	remaining: 13.9s
# 714:	learn: 0.0000055	total: 34.7s	remaining: 13.8s
# 715:	learn: 0.0000055	total: 34.8s	remaining: 13.8s
# 716:	learn: 0.0000055	total: 34.8s	remaining: 13.7s
# 717:	learn: 0.0000055	total: 34.9s	remaining: 13.7s
# 718:	learn: 0.0000055	total: 34.9s	remaining: 13.6s
# 719:	learn: 0.0000054	total: 35s	remaining: 13.6s
# 720:	learn: 0.0000054	total: 35s	remaining: 13.5s
# 721:	learn: 0.0000054	total: 35s	remaining: 13.5s
# 722:	learn: 0.0000054	total: 35.1s	remaining: 13.4s
# 723:	learn: 0.0000054	total: 35.1s	remaining: 13.4s
# 724:	learn: 0.0000054	total: 35.2s	remaining: 13.3s
# 725:	learn: 0.0000054	total: 35.2s	remaining: 13.3s
# 726:	learn: 0.0000054	total: 35.3s	remaining: 13.2s
# 727:	learn: 0.0000054	total: 35.3s	remaining: 13.2s
# 728:	learn: 0.0000054	total: 35.3s	remaining: 13.1s
# 729:	learn: 0.0000054	total: 35.4s	remaining: 13.1s
# 730:	learn: 0.0000054	total: 35.4s	remaining: 13s
# 731:	learn: 0.0000053	total: 35.5s	remaining: 13s
# 732:	learn: 0.0000053	total: 35.5s	remaining: 12.9s
# 733:	learn: 0.0000053	total: 35.6s	remaining: 12.9s
# 734:	learn: 0.0000053	total: 35.6s	remaining: 12.8s
# 735:	learn: 0.0000053	total: 35.7s	remaining: 12.8s
# 736:	learn: 0.0000053	total: 35.7s	remaining: 12.7s
# 737:	learn: 0.0000053	total: 35.7s	remaining: 12.7s
# 738:	learn: 0.0000053	total: 35.8s	remaining: 12.6s
# 739:	learn: 0.0000053	total: 35.8s	remaining: 12.6s
# 740:	learn: 0.0000053	total: 35.9s	remaining: 12.5s
# 741:	learn: 0.0000053	total: 35.9s	remaining: 12.5s
# 742:	learn: 0.0000052	total: 35.9s	remaining: 12.4s
# 743:	learn: 0.0000052	total: 36s	remaining: 12.4s
# 744:	learn: 0.0000052	total: 36s	remaining: 12.3s
# 745:	learn: 0.0000052	total: 36.1s	remaining: 12.3s
# 746:	learn: 0.0000052	total: 36.1s	remaining: 12.2s
# 747:	learn: 0.0000052	total: 36.2s	remaining: 12.2s
# 748:	learn: 0.0000052	total: 36.2s	remaining: 12.1s
# 749:	learn: 0.0000052	total: 36.2s	remaining: 12.1s
# 750:	learn: 0.0000052	total: 36.3s	remaining: 12s
# 751:	learn: 0.0000052	total: 36.3s	remaining: 12s
# 752:	learn: 0.0000051	total: 36.4s	remaining: 11.9s
# 753:	learn: 0.0000051	total: 36.4s	remaining: 11.9s
# 754:	learn: 0.0000051	total: 36.4s	remaining: 11.8s
# 755:	learn: 0.0000051	total: 36.5s	remaining: 11.8s
# 756:	learn: 0.0000051	total: 36.5s	remaining: 11.7s
# 757:	learn: 0.0000051	total: 36.6s	remaining: 11.7s
# 758:	learn: 0.0000051	total: 36.6s	remaining: 11.6s
# 759:	learn: 0.0000051	total: 36.7s	remaining: 11.6s
# 760:	learn: 0.0000051	total: 36.7s	remaining: 11.5s
# 761:	learn: 0.0000051	total: 36.8s	remaining: 11.5s
# 762:	learn: 0.0000051	total: 36.8s	remaining: 11.4s
# 763:	learn: 0.0000051	total: 36.9s	remaining: 11.4s
# 764:	learn: 0.0000051	total: 37s	remaining: 11.4s
# 765:	learn: 0.0000051	total: 37s	remaining: 11.3s
# 766:	learn: 0.0000051	total: 37.1s	remaining: 11.3s
# 767:	learn: 0.0000051	total: 37.1s	remaining: 11.2s
# 768:	learn: 0.0000051	total: 37.1s	remaining: 11.2s
# 769:	learn: 0.0000051	total: 37.2s	remaining: 11.1s
# 770:	learn: 0.0000051	total: 37.2s	remaining: 11.1s
# 771:	learn: 0.0000051	total: 37.3s	remaining: 11s
# 772:	learn: 0.0000050	total: 37.3s	remaining: 11s
# 773:	learn: 0.0000050	total: 37.4s	remaining: 10.9s
# 774:	learn: 0.0000050	total: 37.4s	remaining: 10.9s
# 775:	learn: 0.0000050	total: 37.4s	remaining: 10.8s
# 776:	learn: 0.0000050	total: 37.5s	remaining: 10.8s
# 777:	learn: 0.0000050	total: 37.5s	remaining: 10.7s
# 778:	learn: 0.0000050	total: 37.6s	remaining: 10.7s
# 779:	learn: 0.0000050	total: 37.6s	remaining: 10.6s
# 780:	learn: 0.0000050	total: 37.7s	remaining: 10.6s
# 781:	learn: 0.0000050	total: 37.7s	remaining: 10.5s
# 782:	learn: 0.0000050	total: 37.8s	remaining: 10.5s
# 783:	learn: 0.0000050	total: 37.8s	remaining: 10.4s
# 784:	learn: 0.0000050	total: 37.8s	remaining: 10.4s
# 785:	learn: 0.0000050	total: 37.9s	remaining: 10.3s
# 786:	learn: 0.0000050	total: 37.9s	remaining: 10.3s
# 787:	learn: 0.0000050	total: 38s	remaining: 10.2s
# 788:	learn: 0.0000050	total: 38s	remaining: 10.2s
# 789:	learn: 0.0000050	total: 38.1s	remaining: 10.1s
# 790:	learn: 0.0000049	total: 38.1s	remaining: 10.1s
# 791:	learn: 0.0000049	total: 38.2s	remaining: 10s
# 792:	learn: 0.0000049	total: 38.2s	remaining: 9.97s
# 793:	learn: 0.0000049	total: 38.3s	remaining: 9.92s
# 794:	learn: 0.0000049	total: 38.3s	remaining: 9.87s
# 795:	learn: 0.0000049	total: 38.3s	remaining: 9.83s
# 796:	learn: 0.0000049	total: 38.4s	remaining: 9.78s
# 797:	learn: 0.0000049	total: 38.4s	remaining: 9.73s
# 798:	learn: 0.0000049	total: 38.5s	remaining: 9.68s
# 799:	learn: 0.0000049	total: 38.5s	remaining: 9.63s
# 800:	learn: 0.0000049	total: 38.6s	remaining: 9.59s
# 801:	learn: 0.0000049	total: 38.6s	remaining: 9.54s
# 802:	learn: 0.0000049	total: 38.7s	remaining: 9.49s
# 803:	learn: 0.0000048	total: 38.7s	remaining: 9.44s
# 804:	learn: 0.0000048	total: 38.8s	remaining: 9.39s
# 805:	learn: 0.0000048	total: 38.8s	remaining: 9.34s
# 806:	learn: 0.0000048	total: 38.8s	remaining: 9.29s
# 807:	learn: 0.0000048	total: 38.9s	remaining: 9.23s
# 808:	learn: 0.0000048	total: 38.9s	remaining: 9.19s
# 809:	learn: 0.0000048	total: 38.9s	remaining: 9.13s
# 810:	learn: 0.0000048	total: 39s	remaining: 9.09s
# 811:	learn: 0.0000048	total: 39s	remaining: 9.04s
# 812:	learn: 0.0000048	total: 39.1s	remaining: 8.99s
# 813:	learn: 0.0000048	total: 39.1s	remaining: 8.94s
# 814:	learn: 0.0000048	total: 39.2s	remaining: 8.89s
# 815:	learn: 0.0000048	total: 39.2s	remaining: 8.84s
# 816:	learn: 0.0000048	total: 39.3s	remaining: 8.79s
# 817:	learn: 0.0000048	total: 39.3s	remaining: 8.75s
# 818:	learn: 0.0000048	total: 39.4s	remaining: 8.7s
# 819:	learn: 0.0000047	total: 39.4s	remaining: 8.65s
# 820:	learn: 0.0000047	total: 39.4s	remaining: 8.6s
# 821:	learn: 0.0000047	total: 39.5s	remaining: 8.55s
# 822:	learn: 0.0000047	total: 39.5s	remaining: 8.5s
# 823:	learn: 0.0000047	total: 39.6s	remaining: 8.45s
# 824:	learn: 0.0000047	total: 39.6s	remaining: 8.4s
# 825:	learn: 0.0000047	total: 39.6s	remaining: 8.35s
# 826:	learn: 0.0000047	total: 39.7s	remaining: 8.3s
# 827:	learn: 0.0000047	total: 39.7s	remaining: 8.26s
# 828:	learn: 0.0000047	total: 39.8s	remaining: 8.2s
# 829:	learn: 0.0000047	total: 39.8s	remaining: 8.15s
# 830:	learn: 0.0000047	total: 39.9s	remaining: 8.11s
# 831:	learn: 0.0000047	total: 39.9s	remaining: 8.06s
# 832:	learn: 0.0000047	total: 39.9s	remaining: 8.01s
# 833:	learn: 0.0000047	total: 40s	remaining: 7.96s
# 834:	learn: 0.0000047	total: 40s	remaining: 7.91s
# 835:	learn: 0.0000047	total: 40.1s	remaining: 7.86s
# 836:	learn: 0.0000047	total: 40.1s	remaining: 7.81s
# 837:	learn: 0.0000047	total: 40.2s	remaining: 7.76s
# 838:	learn: 0.0000046	total: 40.2s	remaining: 7.71s
# 839:	learn: 0.0000046	total: 40.2s	remaining: 7.66s
# 840:	learn: 0.0000046	total: 40.3s	remaining: 7.62s
# 841:	learn: 0.0000046	total: 40.3s	remaining: 7.57s
# 842:	learn: 0.0000046	total: 40.4s	remaining: 7.52s
# 843:	learn: 0.0000046	total: 40.4s	remaining: 7.46s
# 844:	learn: 0.0000046	total: 40.4s	remaining: 7.42s
# 845:	learn: 0.0000046	total: 40.5s	remaining: 7.37s
# 846:	learn: 0.0000046	total: 40.5s	remaining: 7.32s
# 847:	learn: 0.0000046	total: 40.6s	remaining: 7.27s
# 848:	learn: 0.0000046	total: 40.6s	remaining: 7.22s
# 849:	learn: 0.0000046	total: 40.6s	remaining: 7.17s
# 850:	learn: 0.0000046	total: 40.7s	remaining: 7.12s
# 851:	learn: 0.0000046	total: 40.7s	remaining: 7.08s
# 852:	learn: 0.0000046	total: 40.8s	remaining: 7.03s
# 853:	learn: 0.0000046	total: 40.8s	remaining: 6.98s
# 854:	learn: 0.0000046	total: 40.9s	remaining: 6.93s
# 855:	learn: 0.0000045	total: 40.9s	remaining: 6.88s
# 856:	learn: 0.0000045	total: 41s	remaining: 6.84s
# 857:	learn: 0.0000045	total: 41s	remaining: 6.79s
# 858:	learn: 0.0000045	total: 41.1s	remaining: 6.74s
# 859:	learn: 0.0000045	total: 41.1s	remaining: 6.7s
# 860:	learn: 0.0000045	total: 41.2s	remaining: 6.65s
# 861:	learn: 0.0000045	total: 41.3s	remaining: 6.6s
# 862:	learn: 0.0000045	total: 41.3s	remaining: 6.56s
# 863:	learn: 0.0000045	total: 41.4s	remaining: 6.51s
# 864:	learn: 0.0000045	total: 41.4s	remaining: 6.46s
# 865:	learn: 0.0000045	total: 41.4s	remaining: 6.41s
# 866:	learn: 0.0000045	total: 41.5s	remaining: 6.36s
# 867:	learn: 0.0000045	total: 41.5s	remaining: 6.32s
# 868:	learn: 0.0000045	total: 41.6s	remaining: 6.27s
# 869:	learn: 0.0000045	total: 41.6s	remaining: 6.22s
# 870:	learn: 0.0000045	total: 41.7s	remaining: 6.17s
# 871:	learn: 0.0000045	total: 41.7s	remaining: 6.12s
# 872:	learn: 0.0000045	total: 41.8s	remaining: 6.07s
# 873:	learn: 0.0000045	total: 41.8s	remaining: 6.02s
# 874:	learn: 0.0000044	total: 41.8s	remaining: 5.98s
# 875:	learn: 0.0000044	total: 41.9s	remaining: 5.93s
# 876:	learn: 0.0000044	total: 41.9s	remaining: 5.88s
# 877:	learn: 0.0000044	total: 42s	remaining: 5.83s
# 878:	learn: 0.0000044	total: 42s	remaining: 5.78s
# 879:	learn: 0.0000044	total: 42.1s	remaining: 5.74s
# 880:	learn: 0.0000044	total: 42.1s	remaining: 5.69s
# 881:	learn: 0.0000044	total: 42.1s	remaining: 5.64s
# 882:	learn: 0.0000044	total: 42.2s	remaining: 5.59s
# 883:	learn: 0.0000044	total: 42.2s	remaining: 5.54s
# 884:	learn: 0.0000044	total: 42.3s	remaining: 5.49s
# 885:	learn: 0.0000044	total: 42.3s	remaining: 5.44s
# 886:	learn: 0.0000044	total: 42.4s	remaining: 5.39s
# 887:	learn: 0.0000044	total: 42.4s	remaining: 5.35s
# 888:	learn: 0.0000044	total: 42.4s	remaining: 5.3s
# 889:	learn: 0.0000044	total: 42.5s	remaining: 5.25s
# 890:	learn: 0.0000044	total: 42.5s	remaining: 5.2s
# 891:	learn: 0.0000044	total: 42.6s	remaining: 5.16s
# 892:	learn: 0.0000043	total: 42.6s	remaining: 5.11s
# 893:	learn: 0.0000043	total: 42.7s	remaining: 5.06s
# 894:	learn: 0.0000043	total: 42.7s	remaining: 5.01s
# 895:	learn: 0.0000043	total: 42.7s	remaining: 4.96s
# 896:	learn: 0.0000043	total: 42.8s	remaining: 4.91s
# 897:	learn: 0.0000043	total: 42.8s	remaining: 4.87s
# 898:	learn: 0.0000043	total: 42.9s	remaining: 4.82s
# 899:	learn: 0.0000043	total: 42.9s	remaining: 4.77s
# 900:	learn: 0.0000043	total: 43s	remaining: 4.72s
# 901:	learn: 0.0000043	total: 43s	remaining: 4.67s
# 902:	learn: 0.0000043	total: 43.1s	remaining: 4.63s
# 903:	learn: 0.0000043	total: 43.1s	remaining: 4.58s
# 904:	learn: 0.0000043	total: 43.1s	remaining: 4.53s
# 905:	learn: 0.0000043	total: 43.2s	remaining: 4.48s
# 906:	learn: 0.0000043	total: 43.2s	remaining: 4.43s
# 907:	learn: 0.0000042	total: 43.3s	remaining: 4.38s
# 908:	learn: 0.0000042	total: 43.3s	remaining: 4.34s
# 909:	learn: 0.0000042	total: 43.4s	remaining: 4.29s
# 910:	learn: 0.0000042	total: 43.4s	remaining: 4.24s
# 911:	learn: 0.0000042	total: 43.5s	remaining: 4.19s
# 912:	learn: 0.0000042	total: 43.5s	remaining: 4.15s
# 913:	learn: 0.0000042	total: 43.6s	remaining: 4.1s
# 914:	learn: 0.0000042	total: 43.6s	remaining: 4.05s
# 915:	learn: 0.0000042	total: 43.7s	remaining: 4s
# 916:	learn: 0.0000042	total: 43.7s	remaining: 3.96s
# 917:	learn: 0.0000042	total: 43.7s	remaining: 3.91s
# 918:	learn: 0.0000042	total: 43.8s	remaining: 3.86s
# 919:	learn: 0.0000042	total: 43.8s	remaining: 3.81s
# 920:	learn: 0.0000042	total: 43.9s	remaining: 3.76s
# 921:	learn: 0.0000042	total: 43.9s	remaining: 3.72s
# 922:	learn: 0.0000042	total: 44s	remaining: 3.67s
# 923:	learn: 0.0000042	total: 44s	remaining: 3.62s
# 924:	learn: 0.0000042	total: 44.1s	remaining: 3.57s
# 925:	learn: 0.0000042	total: 44.1s	remaining: 3.52s
# 926:	learn: 0.0000042	total: 44.2s	remaining: 3.48s
# 927:	learn: 0.0000042	total: 44.2s	remaining: 3.43s
# 928:	learn: 0.0000041	total: 44.2s	remaining: 3.38s
# 929:	learn: 0.0000041	total: 44.3s	remaining: 3.33s
# 930:	learn: 0.0000041	total: 44.3s	remaining: 3.29s
# 931:	learn: 0.0000041	total: 44.4s	remaining: 3.24s
# 932:	learn: 0.0000041	total: 44.4s	remaining: 3.19s
# 933:	learn: 0.0000041	total: 44.5s	remaining: 3.14s
# 934:	learn: 0.0000041	total: 44.5s	remaining: 3.09s
# 935:	learn: 0.0000041	total: 44.6s	remaining: 3.05s
# 936:	learn: 0.0000041	total: 44.6s	remaining: 3s
# 937:	learn: 0.0000041	total: 44.7s	remaining: 2.95s
# 938:	learn: 0.0000041	total: 44.7s	remaining: 2.9s
# 939:	learn: 0.0000041	total: 44.8s	remaining: 2.86s
# 940:	learn: 0.0000041	total: 44.8s	remaining: 2.81s
# 941:	learn: 0.0000041	total: 44.8s	remaining: 2.76s
# 942:	learn: 0.0000041	total: 44.9s	remaining: 2.71s
# 943:	learn: 0.0000041	total: 44.9s	remaining: 2.66s
# 944:	learn: 0.0000041	total: 45s	remaining: 2.62s
# 945:	learn: 0.0000041	total: 45s	remaining: 2.57s
# 946:	learn: 0.0000041	total: 45s	remaining: 2.52s
# 947:	learn: 0.0000041	total: 45.1s	remaining: 2.47s
# 948:	learn: 0.0000041	total: 45.1s	remaining: 2.42s
# 949:	learn: 0.0000041	total: 45.2s	remaining: 2.38s
# 950:	learn: 0.0000041	total: 45.2s	remaining: 2.33s
# 951:	learn: 0.0000040	total: 45.3s	remaining: 2.28s
# 952:	learn: 0.0000040	total: 45.3s	remaining: 2.23s
# 953:	learn: 0.0000040	total: 45.4s	remaining: 2.19s
# 954:	learn: 0.0000040	total: 45.4s	remaining: 2.14s
# 955:	learn: 0.0000040	total: 45.5s	remaining: 2.09s
# 956:	learn: 0.0000040	total: 45.5s	remaining: 2.04s
# 957:	learn: 0.0000040	total: 45.5s	remaining: 2s
# 958:	learn: 0.0000040	total: 45.6s	remaining: 1.95s
# 959:	learn: 0.0000040	total: 45.6s	remaining: 1.9s
# 960:	learn: 0.0000040	total: 45.7s	remaining: 1.85s
# 961:	learn: 0.0000040	total: 45.7s	remaining: 1.81s
# 962:	learn: 0.0000040	total: 45.8s	remaining: 1.76s
# 963:	learn: 0.0000040	total: 45.8s	remaining: 1.71s
# 964:	learn: 0.0000040	total: 45.9s	remaining: 1.66s
# 965:	learn: 0.0000040	total: 45.9s	remaining: 1.62s
# 966:	learn: 0.0000040	total: 46s	remaining: 1.57s
# 967:	learn: 0.0000040	total: 46s	remaining: 1.52s
# 968:	learn: 0.0000040	total: 46.1s	remaining: 1.47s
# 969:	learn: 0.0000040	total: 46.1s	remaining: 1.43s
# 970:	learn: 0.0000040	total: 46.2s	remaining: 1.38s
# 971:	learn: 0.0000039	total: 46.2s	remaining: 1.33s
# 972:	learn: 0.0000039	total: 46.2s	remaining: 1.28s
# 973:	learn: 0.0000039	total: 46.3s	remaining: 1.24s
# 974:	learn: 0.0000039	total: 46.3s	remaining: 1.19s
# 975:	learn: 0.0000039	total: 46.4s	remaining: 1.14s
# 976:	learn: 0.0000039	total: 46.4s	remaining: 1.09s
# 977:	learn: 0.0000039	total: 46.5s	remaining: 1.04s
# 978:	learn: 0.0000039	total: 46.5s	remaining: 998ms
# 979:	learn: 0.0000039	total: 46.6s	remaining: 950ms
# 980:	learn: 0.0000039	total: 46.6s	remaining: 903ms
# 981:	learn: 0.0000039	total: 46.7s	remaining: 855ms
# 982:	learn: 0.0000039	total: 46.7s	remaining: 808ms
# 983:	learn: 0.0000039	total: 46.8s	remaining: 760ms
# 984:	learn: 0.0000039	total: 46.8s	remaining: 713ms
# 985:	learn: 0.0000039	total: 46.9s	remaining: 665ms
# 986:	learn: 0.0000039	total: 46.9s	remaining: 618ms
# 987:	learn: 0.0000039	total: 47s	remaining: 570ms
# 988:	learn: 0.0000039	total: 47s	remaining: 523ms
# 989:	learn: 0.0000039	total: 47s	remaining: 475ms
# 990:	learn: 0.0000039	total: 47.1s	remaining: 428ms
# 991:	learn: 0.0000038	total: 47.1s	remaining: 380ms
# 992:	learn: 0.0000038	total: 47.2s	remaining: 333ms
# 993:	learn: 0.0000038	total: 47.2s	remaining: 285ms
# 994:	learn: 0.0000038	total: 47.3s	remaining: 237ms
# 995:	learn: 0.0000038	total: 47.3s	remaining: 190ms
# 996:	learn: 0.0000038	total: 47.4s	remaining: 143ms
# 997:	learn: 0.0000038	total: 47.4s	remaining: 95ms
# 998:	learn: 0.0000038	total: 47.5s	remaining: 47.5ms
# 999:	learn: 0.0000038	total: 47.5s	remaining: 0us

# %%
# Get predicted classes
predict = model.predict(X_test)
predict.head()
# Out:
# array([['GALAXY'],
#        ['STAR'],
#        ['STAR'],
#        ...,
#        ['STAR'],
#        ['GALAXY'],
#        ['GALAXY']], dtype=object)

# %%
p = pd.DataFrame(predict)
p.head()
# Out:
#         0
# 0  GALAXY
# 1    STAR
# 2    STAR
# 3    STAR
# 4    STAR

# %%
X_test.head()
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 75721  1.237679e+18   16.956890   3.646130  23.33542  21.95143  20.48149
# 80184  1.237662e+18  240.063240   6.134131  17.86033  16.79228  16.43001
# 19864  1.237679e+18   30.887222   1.188710  18.18911  16.89469  16.42161
# 76699  1.237668e+18  247.594401  10.887780  24.99961  21.71203  21.47148
# 92991  1.237679e+18   18.896451  -5.261330  23.76648  21.79737  20.69543
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID   class  \
# 75721  19.60300  19.13094    7712        6       442  4.855017e+18  GALAXY
# 80184  16.30923  16.25873    3894        1       243  2.448928e+18    STAR
# 19864  16.24627  16.18549    7717        1       536  8.255357e+18    STAR
# 76699  21.30532  21.29109    5323        1       134  4.577999e+18    STAR
# 92991  20.23403  19.97464    7881        3       148  8.910472e+18    STAR
#
#        redshift  plate    MJD  fiber_ID
# 75721  0.506237   4312  55511       495
# 80184  0.000345   2175  54612       348
# 19864  0.000004   7332  56683       943
# 76699 -0.000291   4066  55444       326
# 92991 -0.000136   7914  57331       363

# %%
X.iloc[[75721,80184,19864,76699,92991]]
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 75721  1.237679e+18   16.956890   3.646130  23.33542  21.95143  20.48149
# 80184  1.237662e+18  240.063240   6.134131  17.86033  16.79228  16.43001
# 19864  1.237679e+18   30.887222   1.188710  18.18911  16.89469  16.42161
# 76699  1.237668e+18  247.594401  10.887780  24.99961  21.71203  21.47148
# 92991  1.237679e+18   18.896451  -5.261330  23.76648  21.79737  20.69543
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID   class  \
# 75721  19.60300  19.13094    7712        6       442  4.855017e+18  GALAXY
# 80184  16.30923  16.25873    3894        1       243  2.448928e+18    STAR
# 19864  16.24627  16.18549    7717        1       536  8.255357e+18    STAR
# 76699  21.30532  21.29109    5323        1       134  4.577999e+18    STAR
# 92991  20.23403  19.97464    7881        3       148  8.910472e+18    STAR
#
#        redshift  plate    MJD  fiber_ID
# 75721  0.506237   4312  55511       495
# 80184  0.000345   2175  54612       348
# 19864  0.000004   7332  56683       943
# 76699 -0.000291   4066  55444       326
# 92991 -0.000136   7914  57331       363

# %%
from catboost.utils import eval_metric

# %%
#res = pd.DataFrame(y_test).join( pd.DataFrame(predict))
test_pool = Pool( y_test, predict)
metric = eval_metric(y_test, predict, 'Precision')
print(metric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 2
#       1 #res = pd.DataFrame(y_test).join( pd.DataFrame(predict))
# ----> 2 test_pool = Pool( y_test, predict)
#       3 metric = eval_metric(y_test, predict, 'Precision')
#       4 print(metric)
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:707, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     705 if data is not None:
#     706     self._check_data_type(data)
# --> 707     self._check_data_empty(data)
#     708     if pairs is not None and isinstance(data, PATH_TYPES) != isinstance(pairs, PATH_TYPES):
#     709         raise CatBoostError("data and pairs parameters should be the same types.")
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/core.py:880, in Pool._check_data_empty(self, data)
#     878 data_shape = np.shape(data)
#     879 if len(data_shape) == 1 and data_shape[0] > 0:
# --> 880     if isinstance(data[0], Iterable):
#     881         data_shape = tuple(data_shape + tuple([len(data[0])]))
#     882     else:
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
for metric in ('Precision', 'Recall', 'F1'):
    print(metric)
    values = eval_metric(y_test, predict, metric)
    for model, value in zip(clf.classes_, values):
        print(f'class={cls}: {value:.4f}')
    print()
# Out:
# Precision
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 3
#       1 for metric in ('Precision', 'Recall', 'F1'):
#       2     print(metric)
# ----> 3     values = eval_metric(y_test, predict, metric)
#       4     for model, value in zip(clf.classes_, values):
#       5         print(f'class={cls}: {value:.4f}')
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/utils.py:293, in eval_metric(label, approx, metric, weight, group_id, group_weight, subgroup_id, pairs, thread_count)
#     249 """
#     250 Evaluate metrics with raw approxes and labels.
#     251
#    (...)
#     290 metric results : list with metric values.
#     291 """
#     292 if len(label) > 0:
# --> 293     label = np.transpose(label) if isinstance(label[0], ARRAY_TYPES) else [label]
#     294 if len(approx) == 0:
#     295     approx = [[]]
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
model.save_model('astra.cbm')

# %%
X_test.to_csv('astra.csv')

# %%
ff = model.get_feature_importance()
ff
# Out:
# array([ 0.27624387,  0.27778713,  0.1622283 ,  0.10247422,  0.1581494 ,
#         0.25616265,  0.21896545,  0.29039967,  0.27757768,  0.35941504,
#         0.16894315, 91.3056414 ,  5.55423445,  0.15600785,  0.17002827,
#         0.26574147])

# %%
nn = model.get_feature_names()
nn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 nn = model.get_feature_names()
#       2 nn
#
# AttributeError: 'CatBoostClassifier' object has no attribute 'get_feature_names'
