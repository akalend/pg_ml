# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
from catboost import CatBoostClassifier
import pandas as pd

# %%
# !ls sample_data
# Out:
# anscombe.json  california_housing_test.csv   mnist_test.csv	    README.md
# astra.csv      california_housing_train.csv  mnist_train_small.csv  star_classification.csv

# %%
df = pd.read_csv('sample_data/star_classification.csv')

# %%
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2      79.0  6.543777e+18
# 1  21.16812  21.61427    4518       301        5     119.0  1.176014e+19
# 2  19.34857  18.94827    3606       301        2     120.0  5.152200e+18
# 3  20.50454  19.25010    4192       301        3     214.0  1.030107e+19
# 4  15.97711  15.54461    8102       301        3     137.0  6.891865e+18
#
#     class  redshift    plate      MJD  fiber_ID
# 0  GALAXY  0.634794   5812.0  56354.0     171.0
# 1  GALAXY  0.779136  10445.0  58158.0     427.0
# 2  GALAXY  0.644195   4576.0  55592.0     299.0
# 3  GALAXY  0.932346   9149.0  58039.0     775.0
# 4  GALAXY  0.116123   6121.0  56187.0     842.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %%
df.nunique ()
# Out:
# obj_ID          78053
# alpha           99999
# delta           99999
# u               93748
# g               92651
# r               91901
# i               92019
# z               92007
# run_ID            430
# rerun_ID            1
# cam_col             6
# field_ID          856
# spec_obj_ID    100000
# class               3
# redshift        99295
# plate            6284
# MJD              2180
# fiber_ID         1000
# dtype: int64

# %% [markdown]
# ## Background
#
# This dataset contains over 100,000 observations separated into three class types: Galaxies, Quasars, and Stars. In addition to the class,
# each observation has 17 other defining features, several of which are different identification types that were irrelevant for the purposes
# of this analysis. For completeness, I will list them all where now:
#
# * obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS.
#
# * alpha = Right Ascension angle (at J2000 epoch). This is the angle (in degrees) between the Vernal Equinox
# and the desired point on the celestial sphere.
#
# * delta = Declination angle (at J2000 epoch). The is the angle (in degrees) between the celestial equator and
# the desired point on the celestial sphere.
#
# * u = Ultraviolet filter in the photometric system. 3543 Angstroms (354.3 nm)
#
# * g = Green filter in the photometric system. 4770 Angstroms (477.0 nm)
#
# * r = Red filter in the photometric system. 6231 Angstroms (623.1 nm)
#
# * i = Near Infrared filter in the photometric system. 7625 Angstroms (762.5 nm)
#
# * z = Infrared filter in the photometric system. 9134 Angstroms (913.4 nm)
#
# * run_ID = Run Number used to identify the specific scan.
#
# * rereun_ID = Rerun Number to specify how the image was processed.
#
# * cam_col = Camera column to identify the scanline within the run.
#
# * field_ID = Field number to identify each field.
#
# * spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class).
#
# * class = Object class (galaxy, star, or quasar object).
#
# * redshift = Redshift value based on the increase in wavelength. The more red shifted light is, the further it has traveled from its
# point of origin
# Значение красного смещения, основанное на увеличении длины волны. Чем больше смещение света в красный цвет, тем дальше он удалился от своей исходной точки
#
# * plate = Plate ID, identifies each plate in SDSS.
#
# * MJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken.
#
# * fiber_ID = Fiber ID that identifies the fiber that pointed the light at the focal plane in each observation.
# Идентификатор fiber, который идентифицируюет fiber, направившее свет в фокальную плоскость при каждом наблюдении.
#
# As explained earlier, the ID attributes were removed from the table before I began looking for trends.

# %%
df.describe()
# Out:
#          Unnamed: 0        alpha        delta            u            g  \
# count   6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   12522.409650   177.301013    22.803363    22.035703    20.624414
# std     7234.712544    99.696984    19.489059     2.208166     2.024459
# min        3.000000     0.024258   -16.713711    12.262400    10.511390
# 25%     6262.500000   124.318935     3.359029    20.366950    19.023630
# 50%    12417.000000   178.918109    21.250905    22.105980    21.058440
# 75%    18854.500000   235.919281    37.979984    23.606445    22.107225
# max    25033.000000   359.999810    82.764421    29.234380    27.264660
#
#                  r            i            z      cam_col     redshift  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean     19.664890    19.119157    18.803348     3.536188     0.590081
# std       1.856765     1.766980     1.779070     1.594201     0.775760
# min      10.068540    11.299560    10.225510     1.000000    -0.004016
# 25%      18.113130    17.722590    17.471150     2.000000     0.042061
# 50%      20.142000    19.440650    19.035130     4.000000     0.394683
# 75%      21.073310    20.463200    19.975300     5.000000     0.717195
# max      27.397090    25.988820    25.333640     6.000000     7.011245
#
#               plate           MJD     fiber_ID
# count   6259.000000   6259.000000  6259.000000
# mean    5139.240454  55589.647228   448.958460
# std     2959.534656   1813.947643   267.298548
# min      266.000000  51630.000000     1.000000
# 25%     2528.500000  54232.000000   226.000000
# 50%     5005.000000  55888.000000   441.000000
# 75%     7415.000000  56780.000000   637.000000
# max    12547.000000  58932.000000  1000.000000

# %%
df.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %%
# уничтожаем так как одно и тоже число rerun_ID
# а та же друге ID
X = df.drop(['rerun_ID', 'field_ID', 'spec_obj_ID', 'obj_ID', 'run_ID'], axis=1)
X.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    cam_col   class  redshift    plate      MJD  fiber_ID
# 0        2  GALAXY  0.634794   5812.0  56354.0     171.0
# 1        5  GALAXY  0.779136  10445.0  58158.0     427.0
# 2        2  GALAXY  0.644195   4576.0  55592.0     299.0
# 3        3  GALAXY  0.932346   9149.0  58039.0     775.0
# 4        3  GALAXY  0.116123   6121.0  56187.0     842.0

# %%
from sklearn.model_selection import train_test_split

y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.75,
                                                    random_state=42)

# %%
# X_train.head()
X_test2 = X_test.drop('class', axis=1)
X_test2.columns
# Out:
# Index(['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'cam_col', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %%
y_train.head(3)
# Out:
# 62241       QSO
# 1513        QSO
# 56064    GALAXY
# Name: class, dtype: object

# %%
from catboost import FeaturesData

# %%
# model = CatBoostClassifier( loss_function='MultiLogloss',
#                             eval_metric='HammingLoss',
#                            random_seed=21,
#                             iterations=500,
#                             class_names=['GALAXY', 'QSO', 'STAR'])
# # Fit model
train_label = ['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
               'cam_col', 'field_ID', 'spec_obj_ID', 'redshift', 'plate', 'MJD', 'fiber_ID']
cat_features = [ 'run_ID',  'cam_col', 'field_ID', 'plate', 'MJD', 'fiber_ID']

# Get predicted probabilities for each class
#preds_proba = model.predict_proba(eval_data)
# Get predicted RawFormulaVal
#preds_raw = model.predict(eval_data, prediction_type='RawFormulaVal')


X_train2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-96c08cab69f7> in <cell line: 17>()
#      15
#      16
# ---> 17 X_train2.head()
#
# NameError: name 'X_train2' is not defined

# %%
X_tarin2 = X_train.drop(['class'], axis=1)
X_tarin2.head(3)
# Out:
#             alpha      delta         u         g         r         i  \
# 62241    5.809868  -0.078252  23.96439  22.59558  21.69461  21.43943
# 1513     9.155493  26.331388  18.77055  18.31045  17.94533  17.48212
# 56064  227.197354   9.863035  20.43842  18.39553  17.46085  16.98626
#
#               z  cam_col  redshift   plate      MJD  fiber_ID
# 62241  21.38774        3  3.518984  7864.0  56979.0      34.0
# 1513   17.38670        1  0.082576  7660.0  57357.0     928.0
# 56064  16.61003        5  0.107144  1718.0  53850.0     101.0

# %%
model = CatBoostClassifier( cat_features=None ) # классификатор
model.fit(X_tarin2, y_train) # обучение классификатора
# Out:
# Learning rate set to 0.097585
# 0:	learn: 1.1397412	total: 138ms	remaining: 2m 18s
# 1:	learn: 0.9704558	total: 218ms	remaining: 1m 48s
# 2:	learn: 0.8390983	total: 297ms	remaining: 1m 38s
# 3:	learn: 0.7398287	total: 379ms	remaining: 1m 34s
# 4:	learn: 0.6567347	total: 465ms	remaining: 1m 32s
# 5:	learn: 0.5868335	total: 551ms	remaining: 1m 31s
# 6:	learn: 0.5290802	total: 634ms	remaining: 1m 29s
# 7:	learn: 0.4802144	total: 718ms	remaining: 1m 29s
# 8:	learn: 0.4374632	total: 805ms	remaining: 1m 28s
# 9:	learn: 0.4010073	total: 887ms	remaining: 1m 27s
# 10:	learn: 0.3682557	total: 971ms	remaining: 1m 27s
# 11:	learn: 0.3407310	total: 1.02s	remaining: 1m 24s
# 12:	learn: 0.3157022	total: 1.06s	remaining: 1m 20s
# 13:	learn: 0.2944319	total: 1.1s	remaining: 1m 17s
# 14:	learn: 0.2752806	total: 1.14s	remaining: 1m 14s
# 15:	learn: 0.2577089	total: 1.19s	remaining: 1m 13s
# 16:	learn: 0.2418038	total: 1.23s	remaining: 1m 11s
# 17:	learn: 0.2286602	total: 1.28s	remaining: 1m 9s
# 18:	learn: 0.2167276	total: 1.32s	remaining: 1m 7s
# 19:	learn: 0.2060302	total: 1.36s	remaining: 1m 6s
# 20:	learn: 0.1951908	total: 1.4s	remaining: 1m 5s
# 21:	learn: 0.1864937	total: 1.44s	remaining: 1m 4s
# 22:	learn: 0.1779360	total: 1.49s	remaining: 1m 3s
# 23:	learn: 0.1710024	total: 1.53s	remaining: 1m 2s
# 24:	learn: 0.1645215	total: 1.58s	remaining: 1m 1s
# 25:	learn: 0.1584116	total: 1.63s	remaining: 1m
# 26:	learn: 0.1483946	total: 1.66s	remaining: 60s
# 27:	learn: 0.1433127	total: 1.71s	remaining: 59.2s
# 28:	learn: 0.1394390	total: 1.75s	remaining: 58.4s
# 29:	learn: 0.1357572	total: 1.78s	remaining: 57.7s
# 30:	learn: 0.1306129	total: 1.82s	remaining: 57s
# 31:	learn: 0.1253511	total: 1.87s	remaining: 56.5s
# 32:	learn: 0.1215649	total: 1.91s	remaining: 56.1s
# 33:	learn: 0.1186219	total: 1.95s	remaining: 55.5s
# 34:	learn: 0.1155451	total: 1.99s	remaining: 54.9s
# 35:	learn: 0.1125219	total: 2.03s	remaining: 54.4s
# 36:	learn: 0.1100693	total: 2.07s	remaining: 53.9s
# 37:	learn: 0.1075769	total: 2.11s	remaining: 53.5s
# 38:	learn: 0.1057790	total: 2.15s	remaining: 53.1s
# 39:	learn: 0.1037832	total: 2.19s	remaining: 52.7s
# 40:	learn: 0.1019859	total: 2.23s	remaining: 52.3s
# 41:	learn: 0.1005457	total: 2.28s	remaining: 51.9s
# 42:	learn: 0.0992697	total: 2.31s	remaining: 51.5s
# 43:	learn: 0.0976131	total: 2.35s	remaining: 51.1s
# 44:	learn: 0.0966224	total: 2.39s	remaining: 50.7s
# 45:	learn: 0.0954529	total: 2.43s	remaining: 50.4s
# 46:	learn: 0.0940989	total: 2.47s	remaining: 50.1s
# 47:	learn: 0.0933473	total: 2.52s	remaining: 49.9s
# 48:	learn: 0.0923350	total: 2.58s	remaining: 50s
# 49:	learn: 0.0917006	total: 2.62s	remaining: 49.7s
# 50:	learn: 0.0906347	total: 2.66s	remaining: 49.4s
# 51:	learn: 0.0897302	total: 2.7s	remaining: 49.3s
# 52:	learn: 0.0891020	total: 2.75s	remaining: 49.2s
# 53:	learn: 0.0882544	total: 2.79s	remaining: 49s
# 54:	learn: 0.0874923	total: 2.84s	remaining: 48.8s
# 55:	learn: 0.0868198	total: 2.88s	remaining: 48.5s
# 56:	learn: 0.0863078	total: 2.92s	remaining: 48.3s
# 57:	learn: 0.0857275	total: 2.96s	remaining: 48.1s
# 58:	learn: 0.0851995	total: 3s	remaining: 47.9s
# 59:	learn: 0.0845148	total: 3.04s	remaining: 47.6s
# 60:	learn: 0.0840224	total: 3.08s	remaining: 47.4s
# 61:	learn: 0.0836448	total: 3.12s	remaining: 47.2s
# 62:	learn: 0.0835290	total: 3.16s	remaining: 47s
# 63:	learn: 0.0832819	total: 3.2s	remaining: 46.8s
# 64:	learn: 0.0830670	total: 3.23s	remaining: 46.5s
# 65:	learn: 0.0829675	total: 3.27s	remaining: 46.3s
# 66:	learn: 0.0826596	total: 3.3s	remaining: 46s
# 67:	learn: 0.0819751	total: 3.35s	remaining: 45.9s
# 68:	learn: 0.0816635	total: 3.39s	remaining: 45.7s
# 69:	learn: 0.0815665	total: 3.43s	remaining: 45.5s
# 70:	learn: 0.0814750	total: 3.46s	remaining: 45.3s
# 71:	learn: 0.0811501	total: 3.5s	remaining: 45.2s
# 72:	learn: 0.0810054	total: 3.54s	remaining: 44.9s
# 73:	learn: 0.0806730	total: 3.59s	remaining: 44.9s
# 74:	learn: 0.0803756	total: 3.63s	remaining: 44.8s
# 75:	learn: 0.0802941	total: 3.67s	remaining: 44.6s
# 76:	learn: 0.0802216	total: 3.7s	remaining: 44.4s
# 77:	learn: 0.0799268	total: 3.75s	remaining: 44.3s
# 78:	learn: 0.0798104	total: 3.78s	remaining: 44.1s
# 79:	learn: 0.0796919	total: 3.82s	remaining: 43.9s
# 80:	learn: 0.0795079	total: 3.86s	remaining: 43.8s
# 81:	learn: 0.0793677	total: 3.9s	remaining: 43.7s
# 82:	learn: 0.0790922	total: 3.94s	remaining: 43.5s
# 83:	learn: 0.0788334	total: 3.98s	remaining: 43.4s
# 84:	learn: 0.0787368	total: 4.01s	remaining: 43.2s
# 85:	learn: 0.0786756	total: 4.05s	remaining: 43.1s
# 86:	learn: 0.0785554	total: 4.1s	remaining: 43s
# 87:	learn: 0.0785009	total: 4.13s	remaining: 42.8s
# 88:	learn: 0.0782234	total: 4.18s	remaining: 42.8s
# 89:	learn: 0.0780987	total: 4.22s	remaining: 42.6s
# 90:	learn: 0.0779346	total: 4.26s	remaining: 42.5s
# 91:	learn: 0.0778074	total: 4.29s	remaining: 42.4s
# 92:	learn: 0.0777404	total: 4.33s	remaining: 42.3s
# 93:	learn: 0.0776631	total: 4.37s	remaining: 42.1s
# 94:	learn: 0.0774505	total: 4.41s	remaining: 42s
# 95:	learn: 0.0772734	total: 4.45s	remaining: 41.9s
# 96:	learn: 0.0771093	total: 4.49s	remaining: 41.8s
# 97:	learn: 0.0768768	total: 4.53s	remaining: 41.7s
# 98:	learn: 0.0768283	total: 4.58s	remaining: 41.7s
# 99:	learn: 0.0766493	total: 4.63s	remaining: 41.6s
# 100:	learn: 0.0765436	total: 4.66s	remaining: 41.5s
# 101:	learn: 0.0765025	total: 4.7s	remaining: 41.4s
# 102:	learn: 0.0763554	total: 4.75s	remaining: 41.3s
# 103:	learn: 0.0762034	total: 4.79s	remaining: 41.3s
# 104:	learn: 0.0760229	total: 4.83s	remaining: 41.1s
# 105:	learn: 0.0758935	total: 4.87s	remaining: 41s
# 106:	learn: 0.0756348	total: 4.91s	remaining: 41s
# 107:	learn: 0.0756166	total: 4.95s	remaining: 40.9s
# 108:	learn: 0.0755797	total: 4.99s	remaining: 40.8s
# 109:	learn: 0.0755100	total: 5.03s	remaining: 40.7s
# 110:	learn: 0.0754675	total: 5.07s	remaining: 40.6s
# 111:	learn: 0.0753818	total: 5.1s	remaining: 40.4s
# 112:	learn: 0.0753379	total: 5.14s	remaining: 40.3s
# 113:	learn: 0.0753066	total: 5.17s	remaining: 40.2s
# 114:	learn: 0.0751642	total: 5.21s	remaining: 40.1s
# 115:	learn: 0.0750316	total: 5.26s	remaining: 40.1s
# 116:	learn: 0.0749943	total: 5.29s	remaining: 39.9s
# 117:	learn: 0.0748523	total: 5.33s	remaining: 39.8s
# 118:	learn: 0.0747807	total: 5.37s	remaining: 39.7s
# 119:	learn: 0.0746370	total: 5.41s	remaining: 39.6s
# 120:	learn: 0.0745895	total: 5.44s	remaining: 39.5s
# 121:	learn: 0.0745488	total: 5.48s	remaining: 39.5s
# 122:	learn: 0.0744865	total: 5.52s	remaining: 39.4s
# 123:	learn: 0.0744671	total: 5.56s	remaining: 39.3s
# 124:	learn: 0.0743514	total: 5.6s	remaining: 39.2s
# 125:	learn: 0.0742498	total: 5.65s	remaining: 39.2s
# 126:	learn: 0.0741796	total: 5.69s	remaining: 39.1s
# 127:	learn: 0.0741451	total: 5.73s	remaining: 39s
# 128:	learn: 0.0740631	total: 5.76s	remaining: 38.9s
# 129:	learn: 0.0739266	total: 5.8s	remaining: 38.8s
# 130:	learn: 0.0737982	total: 5.85s	remaining: 38.8s
# 131:	learn: 0.0736655	total: 5.89s	remaining: 38.7s
# 132:	learn: 0.0736025	total: 5.92s	remaining: 38.6s
# 133:	learn: 0.0735760	total: 5.96s	remaining: 38.5s
# 134:	learn: 0.0735122	total: 5.99s	remaining: 38.4s
# 135:	learn: 0.0734760	total: 6.03s	remaining: 38.3s
# 136:	learn: 0.0733713	total: 6.07s	remaining: 38.2s
# 137:	learn: 0.0732913	total: 6.11s	remaining: 38.2s
# 138:	learn: 0.0731895	total: 6.15s	remaining: 38.1s
# 139:	learn: 0.0730880	total: 6.19s	remaining: 38s
# 140:	learn: 0.0729998	total: 6.23s	remaining: 37.9s
# 141:	learn: 0.0729855	total: 6.26s	remaining: 37.8s
# 142:	learn: 0.0729160	total: 6.3s	remaining: 37.8s
# 143:	learn: 0.0728740	total: 6.34s	remaining: 37.7s
# 144:	learn: 0.0728274	total: 6.38s	remaining: 37.6s
# 145:	learn: 0.0727367	total: 6.41s	remaining: 37.5s
# 146:	learn: 0.0723862	total: 6.45s	remaining: 37.4s
# 147:	learn: 0.0723368	total: 6.49s	remaining: 37.4s
# 148:	learn: 0.0722764	total: 6.52s	remaining: 37.3s
# 149:	learn: 0.0722091	total: 6.56s	remaining: 37.2s
# 150:	learn: 0.0721600	total: 6.61s	remaining: 37.2s
# 151:	learn: 0.0721576	total: 6.64s	remaining: 37s
# 152:	learn: 0.0721159	total: 6.68s	remaining: 37s
# 153:	learn: 0.0720399	total: 6.72s	remaining: 36.9s
# 154:	learn: 0.0719265	total: 6.77s	remaining: 36.9s
# 155:	learn: 0.0719034	total: 6.8s	remaining: 36.8s
# 156:	learn: 0.0718648	total: 6.84s	remaining: 36.7s
# 157:	learn: 0.0717634	total: 6.88s	remaining: 36.7s
# 158:	learn: 0.0717236	total: 6.91s	remaining: 36.6s
# 159:	learn: 0.0716598	total: 6.95s	remaining: 36.5s
# 160:	learn: 0.0716088	total: 6.99s	remaining: 36.4s
# 161:	learn: 0.0715539	total: 7.03s	remaining: 36.3s
# 162:	learn: 0.0714563	total: 7.07s	remaining: 36.3s
# 163:	learn: 0.0714299	total: 7.1s	remaining: 36.2s
# 164:	learn: 0.0714029	total: 7.14s	remaining: 36.1s
# 165:	learn: 0.0713494	total: 7.18s	remaining: 36.1s
# 166:	learn: 0.0713178	total: 7.22s	remaining: 36s
# 167:	learn: 0.0712762	total: 7.26s	remaining: 36s
# 168:	learn: 0.0712181	total: 7.29s	remaining: 35.9s
# 169:	learn: 0.0710890	total: 7.34s	remaining: 35.8s
# 170:	learn: 0.0710238	total: 7.38s	remaining: 35.8s
# 171:	learn: 0.0709897	total: 7.41s	remaining: 35.7s
# 172:	learn: 0.0709564	total: 7.45s	remaining: 35.6s
# 173:	learn: 0.0708740	total: 7.49s	remaining: 35.5s
# 174:	learn: 0.0708402	total: 7.52s	remaining: 35.5s
# 175:	learn: 0.0707648	total: 7.56s	remaining: 35.4s
# 176:	learn: 0.0707287	total: 7.61s	remaining: 35.4s
# 177:	learn: 0.0705864	total: 7.65s	remaining: 35.3s
# 178:	learn: 0.0705494	total: 7.69s	remaining: 35.3s
# 179:	learn: 0.0704274	total: 7.74s	remaining: 35.3s
# 180:	learn: 0.0703932	total: 7.78s	remaining: 35.2s
# 181:	learn: 0.0703225	total: 7.81s	remaining: 35.1s
# 182:	learn: 0.0703014	total: 7.84s	remaining: 35s
# 183:	learn: 0.0702702	total: 7.88s	remaining: 35s
# 184:	learn: 0.0702380	total: 7.92s	remaining: 34.9s
# 185:	learn: 0.0701765	total: 7.96s	remaining: 34.8s
# 186:	learn: 0.0701261	total: 8s	remaining: 34.8s
# 187:	learn: 0.0700800	total: 8.03s	remaining: 34.7s
# 188:	learn: 0.0700206	total: 8.07s	remaining: 34.6s
# 189:	learn: 0.0699582	total: 8.11s	remaining: 34.6s
# 190:	learn: 0.0699021	total: 8.15s	remaining: 34.5s
# 191:	learn: 0.0698326	total: 8.19s	remaining: 34.4s
# 192:	learn: 0.0698014	total: 8.22s	remaining: 34.4s
# 193:	learn: 0.0697546	total: 8.26s	remaining: 34.3s
# 194:	learn: 0.0697010	total: 8.29s	remaining: 34.2s
# 195:	learn: 0.0696380	total: 8.33s	remaining: 34.2s
# 196:	learn: 0.0695981	total: 8.37s	remaining: 34.1s
# 197:	learn: 0.0695442	total: 8.41s	remaining: 34.1s
# 198:	learn: 0.0694882	total: 8.44s	remaining: 34s
# 199:	learn: 0.0694612	total: 8.48s	remaining: 33.9s
# 200:	learn: 0.0694225	total: 8.52s	remaining: 33.9s
# 201:	learn: 0.0693695	total: 8.55s	remaining: 33.8s
# 202:	learn: 0.0693549	total: 8.6s	remaining: 33.7s
# 203:	learn: 0.0691672	total: 8.64s	remaining: 33.7s
# 204:	learn: 0.0691396	total: 8.69s	remaining: 33.7s
# 205:	learn: 0.0691143	total: 8.73s	remaining: 33.6s
# 206:	learn: 0.0690669	total: 8.76s	remaining: 33.6s
# 207:	learn: 0.0689949	total: 8.8s	remaining: 33.5s
# 208:	learn: 0.0689532	total: 8.84s	remaining: 33.4s
# 209:	learn: 0.0689050	total: 8.88s	remaining: 33.4s
# 210:	learn: 0.0687474	total: 8.91s	remaining: 33.3s
# 211:	learn: 0.0687131	total: 8.95s	remaining: 33.3s
# 212:	learn: 0.0687121	total: 8.97s	remaining: 33.2s
# 213:	learn: 0.0686826	total: 9.01s	remaining: 33.1s
# 214:	learn: 0.0686436	total: 9.05s	remaining: 33s
# 215:	learn: 0.0685911	total: 9.08s	remaining: 33s
# 216:	learn: 0.0685445	total: 9.12s	remaining: 32.9s
# 217:	learn: 0.0684737	total: 9.16s	remaining: 32.9s
# 218:	learn: 0.0684550	total: 9.19s	remaining: 32.8s
# 219:	learn: 0.0684020	total: 9.23s	remaining: 32.7s
# 220:	learn: 0.0683859	total: 9.27s	remaining: 32.7s
# 221:	learn: 0.0683681	total: 9.3s	remaining: 32.6s
# 222:	learn: 0.0682278	total: 9.34s	remaining: 32.5s
# 223:	learn: 0.0682052	total: 9.38s	remaining: 32.5s
# 224:	learn: 0.0681079	total: 9.41s	remaining: 32.4s
# 225:	learn: 0.0680903	total: 9.45s	remaining: 32.4s
# 226:	learn: 0.0680750	total: 9.49s	remaining: 32.3s
# 227:	learn: 0.0680064	total: 9.53s	remaining: 32.3s
# 228:	learn: 0.0679528	total: 9.57s	remaining: 32.2s
# 229:	learn: 0.0679087	total: 9.6s	remaining: 32.2s
# 230:	learn: 0.0676752	total: 9.64s	remaining: 32.1s
# 231:	learn: 0.0676533	total: 9.7s	remaining: 32.1s
# 232:	learn: 0.0676139	total: 9.73s	remaining: 32s
# 233:	learn: 0.0675231	total: 9.77s	remaining: 32s
# 234:	learn: 0.0674766	total: 9.81s	remaining: 31.9s
# 235:	learn: 0.0673747	total: 9.85s	remaining: 31.9s
# 236:	learn: 0.0673032	total: 9.89s	remaining: 31.8s
# 237:	learn: 0.0672849	total: 9.92s	remaining: 31.8s
# 238:	learn: 0.0672572	total: 9.96s	remaining: 31.7s
# 239:	learn: 0.0672086	total: 9.99s	remaining: 31.7s
# 240:	learn: 0.0671803	total: 10s	remaining: 31.6s
# 241:	learn: 0.0671172	total: 10.1s	remaining: 31.5s
# 242:	learn: 0.0670665	total: 10.1s	remaining: 31.5s
# 243:	learn: 0.0669433	total: 10.2s	remaining: 31.4s
# 244:	learn: 0.0669195	total: 10.2s	remaining: 31.4s
# 245:	learn: 0.0668825	total: 10.2s	remaining: 31.3s
# 246:	learn: 0.0668245	total: 10.3s	remaining: 31.3s
# 247:	learn: 0.0667942	total: 10.3s	remaining: 31.2s
# 248:	learn: 0.0667686	total: 10.3s	remaining: 31.2s
# 249:	learn: 0.0667260	total: 10.4s	remaining: 31.1s
# 250:	learn: 0.0667035	total: 10.4s	remaining: 31s
# 251:	learn: 0.0666342	total: 10.4s	remaining: 31s
# 252:	learn: 0.0666082	total: 10.5s	remaining: 30.9s
# 253:	learn: 0.0665774	total: 10.5s	remaining: 30.9s
# 254:	learn: 0.0665660	total: 10.5s	remaining: 30.8s
# 255:	learn: 0.0664818	total: 10.6s	remaining: 30.8s
# 256:	learn: 0.0664270	total: 10.6s	remaining: 30.7s
# 257:	learn: 0.0664027	total: 10.7s	remaining: 30.7s
# 258:	learn: 0.0663700	total: 10.7s	remaining: 30.6s
# 259:	learn: 0.0663439	total: 10.7s	remaining: 30.6s
# 260:	learn: 0.0663300	total: 10.8s	remaining: 30.5s
# 261:	learn: 0.0662520	total: 10.8s	remaining: 30.5s
# 262:	learn: 0.0662185	total: 10.9s	remaining: 30.4s
# 263:	learn: 0.0661611	total: 10.9s	remaining: 30.4s
# 264:	learn: 0.0661230	total: 10.9s	remaining: 30.3s
# 265:	learn: 0.0661046	total: 11s	remaining: 30.4s
# 266:	learn: 0.0660643	total: 11.1s	remaining: 30.4s
# 267:	learn: 0.0660455	total: 11.1s	remaining: 30.4s
# 268:	learn: 0.0659305	total: 11.2s	remaining: 30.5s
# 269:	learn: 0.0659092	total: 11.3s	remaining: 30.5s
# 270:	learn: 0.0658591	total: 11.4s	remaining: 30.6s
# 271:	learn: 0.0658011	total: 11.4s	remaining: 30.6s
# 272:	learn: 0.0657755	total: 11.5s	remaining: 30.5s
# 273:	learn: 0.0657218	total: 11.5s	remaining: 30.5s
# 274:	learn: 0.0657108	total: 11.6s	remaining: 30.5s
# 275:	learn: 0.0656464	total: 11.6s	remaining: 30.5s
# 276:	learn: 0.0656032	total: 11.7s	remaining: 30.5s
# 277:	learn: 0.0655268	total: 11.8s	remaining: 30.6s
# 278:	learn: 0.0655049	total: 11.8s	remaining: 30.5s
# 279:	learn: 0.0654547	total: 11.9s	remaining: 30.6s
# 280:	learn: 0.0654212	total: 12s	remaining: 30.6s
# 281:	learn: 0.0653603	total: 12s	remaining: 30.6s
# 282:	learn: 0.0653374	total: 12.1s	remaining: 30.6s
# 283:	learn: 0.0653148	total: 12.2s	remaining: 30.7s
# 284:	learn: 0.0652725	total: 12.3s	remaining: 30.7s
# 285:	learn: 0.0652514	total: 12.3s	remaining: 30.8s
# 286:	learn: 0.0651994	total: 12.4s	remaining: 30.8s
# 287:	learn: 0.0651787	total: 12.5s	remaining: 30.9s
# 288:	learn: 0.0651512	total: 12.6s	remaining: 30.9s
# 289:	learn: 0.0650828	total: 12.7s	remaining: 31s
# 290:	learn: 0.0650262	total: 12.7s	remaining: 31.1s
# 291:	learn: 0.0649956	total: 12.8s	remaining: 31.1s
# 292:	learn: 0.0649555	total: 12.9s	remaining: 31.1s
# 293:	learn: 0.0648947	total: 13s	remaining: 31.2s
# 294:	learn: 0.0648657	total: 13.1s	remaining: 31.2s
# 295:	learn: 0.0648283	total: 13.1s	remaining: 31.2s
# 296:	learn: 0.0648035	total: 13.2s	remaining: 31.2s
# 297:	learn: 0.0647730	total: 13.3s	remaining: 31.3s
# 298:	learn: 0.0647362	total: 13.3s	remaining: 31.3s
# 299:	learn: 0.0646878	total: 13.4s	remaining: 31.3s
# 300:	learn: 0.0646206	total: 13.5s	remaining: 31.4s
# 301:	learn: 0.0645957	total: 13.6s	remaining: 31.4s
# 302:	learn: 0.0645681	total: 13.7s	remaining: 31.4s
# 303:	learn: 0.0645367	total: 13.7s	remaining: 31.4s
# 304:	learn: 0.0644922	total: 13.8s	remaining: 31.4s
# 305:	learn: 0.0644444	total: 13.8s	remaining: 31.4s
# 306:	learn: 0.0643452	total: 13.9s	remaining: 31.3s
# 307:	learn: 0.0643233	total: 13.9s	remaining: 31.2s
# 308:	learn: 0.0642897	total: 13.9s	remaining: 31.2s
# 309:	learn: 0.0642677	total: 14s	remaining: 31.1s
# 310:	learn: 0.0641857	total: 14s	remaining: 31.1s
# 311:	learn: 0.0640848	total: 14.1s	remaining: 31s
# 312:	learn: 0.0640252	total: 14.1s	remaining: 31s
# 313:	learn: 0.0639738	total: 14.1s	remaining: 30.9s
# 314:	learn: 0.0639443	total: 14.2s	remaining: 30.8s
# 315:	learn: 0.0639118	total: 14.2s	remaining: 30.8s
# 316:	learn: 0.0638948	total: 14.3s	remaining: 30.7s
# 317:	learn: 0.0638789	total: 14.3s	remaining: 30.7s
# 318:	learn: 0.0637939	total: 14.3s	remaining: 30.6s
# 319:	learn: 0.0637374	total: 14.4s	remaining: 30.5s
# 320:	learn: 0.0637175	total: 14.4s	remaining: 30.5s
# 321:	learn: 0.0636129	total: 14.4s	remaining: 30.4s
# 322:	learn: 0.0635600	total: 14.5s	remaining: 30.4s
# 323:	learn: 0.0635058	total: 14.5s	remaining: 30.3s
# 324:	learn: 0.0634465	total: 14.6s	remaining: 30.3s
# 325:	learn: 0.0634247	total: 14.6s	remaining: 30.2s
# 326:	learn: 0.0633376	total: 14.6s	remaining: 30.1s
# 327:	learn: 0.0633217	total: 14.7s	remaining: 30.1s
# 328:	learn: 0.0632871	total: 14.7s	remaining: 30s
# 329:	learn: 0.0632277	total: 14.8s	remaining: 30s
# 330:	learn: 0.0631980	total: 14.8s	remaining: 29.9s
# 331:	learn: 0.0631384	total: 14.9s	remaining: 29.9s
# 332:	learn: 0.0631152	total: 14.9s	remaining: 29.9s
# 333:	learn: 0.0630694	total: 14.9s	remaining: 29.8s
# 334:	learn: 0.0630197	total: 15s	remaining: 29.7s
# 335:	learn: 0.0629771	total: 15s	remaining: 29.7s
# 336:	learn: 0.0629498	total: 15.1s	remaining: 29.6s
# 337:	learn: 0.0629404	total: 15.1s	remaining: 29.6s
# 338:	learn: 0.0629068	total: 15.1s	remaining: 29.5s
# 339:	learn: 0.0628602	total: 15.2s	remaining: 29.4s
# 340:	learn: 0.0628355	total: 15.2s	remaining: 29.4s
# 341:	learn: 0.0628148	total: 15.2s	remaining: 29.3s
# 342:	learn: 0.0627720	total: 15.3s	remaining: 29.3s
# 343:	learn: 0.0627048	total: 15.3s	remaining: 29.2s
# 344:	learn: 0.0626684	total: 15.4s	remaining: 29.2s
# 345:	learn: 0.0626122	total: 15.4s	remaining: 29.1s
# 346:	learn: 0.0625609	total: 15.4s	remaining: 29.1s
# 347:	learn: 0.0625271	total: 15.5s	remaining: 29s
# 348:	learn: 0.0624988	total: 15.5s	remaining: 29s
# 349:	learn: 0.0624755	total: 15.6s	remaining: 28.9s
# 350:	learn: 0.0624469	total: 15.6s	remaining: 28.9s
# 351:	learn: 0.0623630	total: 15.7s	remaining: 28.8s
# 352:	learn: 0.0623200	total: 15.7s	remaining: 28.8s
# 353:	learn: 0.0623121	total: 15.7s	remaining: 28.7s
# 354:	learn: 0.0622558	total: 15.8s	remaining: 28.7s
# 355:	learn: 0.0622322	total: 15.8s	remaining: 28.6s
# 356:	learn: 0.0622062	total: 15.9s	remaining: 28.6s
# 357:	learn: 0.0621828	total: 15.9s	remaining: 28.5s
# 358:	learn: 0.0621659	total: 15.9s	remaining: 28.5s
# 359:	learn: 0.0621103	total: 16s	remaining: 28.4s
# 360:	learn: 0.0620750	total: 16s	remaining: 28.4s
# 361:	learn: 0.0620493	total: 16.1s	remaining: 28.3s
# 362:	learn: 0.0620289	total: 16.1s	remaining: 28.3s
# 363:	learn: 0.0619968	total: 16.1s	remaining: 28.2s
# 364:	learn: 0.0619691	total: 16.2s	remaining: 28.1s
# 365:	learn: 0.0619444	total: 16.2s	remaining: 28.1s
# 366:	learn: 0.0619021	total: 16.2s	remaining: 28s
# 367:	learn: 0.0618624	total: 16.3s	remaining: 28s
# 368:	learn: 0.0618071	total: 16.3s	remaining: 27.9s
# 369:	learn: 0.0617652	total: 16.4s	remaining: 27.9s
# 370:	learn: 0.0617201	total: 16.4s	remaining: 27.8s
# 371:	learn: 0.0616860	total: 16.5s	remaining: 27.8s
# 372:	learn: 0.0616626	total: 16.5s	remaining: 27.7s
# 373:	learn: 0.0616424	total: 16.5s	remaining: 27.7s
# 374:	learn: 0.0615999	total: 16.6s	remaining: 27.6s
# 375:	learn: 0.0615793	total: 16.6s	remaining: 27.5s
# 376:	learn: 0.0615211	total: 16.6s	remaining: 27.5s
# 377:	learn: 0.0614699	total: 16.7s	remaining: 27.4s
# 378:	learn: 0.0614508	total: 16.7s	remaining: 27.4s
# 379:	learn: 0.0614075	total: 16.8s	remaining: 27.3s
# 380:	learn: 0.0613839	total: 16.8s	remaining: 27.3s
# 381:	learn: 0.0613485	total: 16.8s	remaining: 27.2s
# 382:	learn: 0.0613177	total: 16.9s	remaining: 27.2s
# 383:	learn: 0.0613010	total: 16.9s	remaining: 27.1s
# 384:	learn: 0.0612612	total: 17s	remaining: 27.1s
# 385:	learn: 0.0612347	total: 17s	remaining: 27s
# 386:	learn: 0.0612038	total: 17s	remaining: 27s
# 387:	learn: 0.0611901	total: 17.1s	remaining: 26.9s
# 388:	learn: 0.0611638	total: 17.1s	remaining: 26.9s
# 389:	learn: 0.0611337	total: 17.2s	remaining: 26.8s
# 390:	learn: 0.0610854	total: 17.2s	remaining: 26.8s
# 391:	learn: 0.0610543	total: 17.2s	remaining: 26.7s
# 392:	learn: 0.0610179	total: 17.3s	remaining: 26.7s
# 393:	learn: 0.0609768	total: 17.3s	remaining: 26.6s
# 394:	learn: 0.0609604	total: 17.4s	remaining: 26.6s
# 395:	learn: 0.0609246	total: 17.4s	remaining: 26.5s
# 396:	learn: 0.0608927	total: 17.4s	remaining: 26.5s
# 397:	learn: 0.0608712	total: 17.5s	remaining: 26.4s
# 398:	learn: 0.0608449	total: 17.5s	remaining: 26.4s
# 399:	learn: 0.0607702	total: 17.6s	remaining: 26.3s
# 400:	learn: 0.0607553	total: 17.6s	remaining: 26.3s
# 401:	learn: 0.0607292	total: 17.6s	remaining: 26.2s
# 402:	learn: 0.0607100	total: 17.7s	remaining: 26.2s
# 403:	learn: 0.0606701	total: 17.7s	remaining: 26.1s
# 404:	learn: 0.0605980	total: 17.8s	remaining: 26.1s
# 405:	learn: 0.0605654	total: 17.8s	remaining: 26s
# 406:	learn: 0.0604202	total: 17.8s	remaining: 26s
# 407:	learn: 0.0603488	total: 17.9s	remaining: 26s
# 408:	learn: 0.0602930	total: 17.9s	remaining: 25.9s
# 409:	learn: 0.0602643	total: 18s	remaining: 25.8s
# 410:	learn: 0.0602428	total: 18s	remaining: 25.8s
# 411:	learn: 0.0601755	total: 18s	remaining: 25.8s
# 412:	learn: 0.0601448	total: 18.1s	remaining: 25.7s
# 413:	learn: 0.0600978	total: 18.1s	remaining: 25.7s
# 414:	learn: 0.0600638	total: 18.2s	remaining: 25.6s
# 415:	learn: 0.0600395	total: 18.2s	remaining: 25.6s
# 416:	learn: 0.0600140	total: 18.2s	remaining: 25.5s
# 417:	learn: 0.0599820	total: 18.3s	remaining: 25.5s
# 418:	learn: 0.0599528	total: 18.3s	remaining: 25.4s
# 419:	learn: 0.0599334	total: 18.4s	remaining: 25.4s
# 420:	learn: 0.0598835	total: 18.4s	remaining: 25.3s
# 421:	learn: 0.0598560	total: 18.4s	remaining: 25.3s
# 422:	learn: 0.0598242	total: 18.5s	remaining: 25.2s
# 423:	learn: 0.0597717	total: 18.5s	remaining: 25.2s
# 424:	learn: 0.0597441	total: 18.6s	remaining: 25.1s
# 425:	learn: 0.0597158	total: 18.6s	remaining: 25.1s
# 426:	learn: 0.0596808	total: 18.6s	remaining: 25s
# 427:	learn: 0.0596433	total: 18.7s	remaining: 25s
# 428:	learn: 0.0596003	total: 18.7s	remaining: 24.9s
# 429:	learn: 0.0595854	total: 18.8s	remaining: 24.9s
# 430:	learn: 0.0595578	total: 18.8s	remaining: 24.8s
# 431:	learn: 0.0594709	total: 18.8s	remaining: 24.8s
# 432:	learn: 0.0594475	total: 18.9s	remaining: 24.7s
# 433:	learn: 0.0594221	total: 18.9s	remaining: 24.7s
# 434:	learn: 0.0593994	total: 19s	remaining: 24.6s
# 435:	learn: 0.0593591	total: 19s	remaining: 24.6s
# 436:	learn: 0.0593291	total: 19s	remaining: 24.5s
# 437:	learn: 0.0592630	total: 19.1s	remaining: 24.5s
# 438:	learn: 0.0592493	total: 19.1s	remaining: 24.4s
# 439:	learn: 0.0592168	total: 19.2s	remaining: 24.4s
# 440:	learn: 0.0591469	total: 19.2s	remaining: 24.3s
# 441:	learn: 0.0591387	total: 19.2s	remaining: 24.3s
# 442:	learn: 0.0591036	total: 19.3s	remaining: 24.2s
# 443:	learn: 0.0590933	total: 19.3s	remaining: 24.2s
# 444:	learn: 0.0590788	total: 19.4s	remaining: 24.1s
# 445:	learn: 0.0590703	total: 19.4s	remaining: 24.1s
# 446:	learn: 0.0590437	total: 19.4s	remaining: 24s
# 447:	learn: 0.0590126	total: 19.5s	remaining: 24s
# 448:	learn: 0.0589832	total: 19.5s	remaining: 24s
# 449:	learn: 0.0589627	total: 19.6s	remaining: 23.9s
# 450:	learn: 0.0589347	total: 19.6s	remaining: 23.9s
# 451:	learn: 0.0589095	total: 19.6s	remaining: 23.8s
# 452:	learn: 0.0588808	total: 19.7s	remaining: 23.8s
# 453:	learn: 0.0588568	total: 19.7s	remaining: 23.7s
# 454:	learn: 0.0588260	total: 19.8s	remaining: 23.7s
# 455:	learn: 0.0588135	total: 19.8s	remaining: 23.6s
# 456:	learn: 0.0587993	total: 19.8s	remaining: 23.6s
# 457:	learn: 0.0587881	total: 19.9s	remaining: 23.5s
# 458:	learn: 0.0587466	total: 19.9s	remaining: 23.5s
# 459:	learn: 0.0587128	total: 20s	remaining: 23.4s
# 460:	learn: 0.0586848	total: 20s	remaining: 23.4s
# 461:	learn: 0.0586545	total: 20s	remaining: 23.3s
# 462:	learn: 0.0586264	total: 20.1s	remaining: 23.3s
# 463:	learn: 0.0585887	total: 20.1s	remaining: 23.2s
# 464:	learn: 0.0585510	total: 20.2s	remaining: 23.2s
# 465:	learn: 0.0585324	total: 20.2s	remaining: 23.1s
# 466:	learn: 0.0585063	total: 20.2s	remaining: 23.1s
# 467:	learn: 0.0584784	total: 20.3s	remaining: 23.1s
# 468:	learn: 0.0584705	total: 20.3s	remaining: 23s
# 469:	learn: 0.0584500	total: 20.4s	remaining: 23s
# 470:	learn: 0.0583865	total: 20.4s	remaining: 22.9s
# 471:	learn: 0.0583598	total: 20.4s	remaining: 22.9s
# 472:	learn: 0.0583368	total: 20.5s	remaining: 22.8s
# 473:	learn: 0.0583131	total: 20.5s	remaining: 22.8s
# 474:	learn: 0.0582820	total: 20.5s	remaining: 22.7s
# 475:	learn: 0.0582445	total: 20.6s	remaining: 22.7s
# 476:	learn: 0.0582183	total: 20.6s	remaining: 22.6s
# 477:	learn: 0.0581927	total: 20.7s	remaining: 22.6s
# 478:	learn: 0.0581800	total: 20.7s	remaining: 22.5s
# 479:	learn: 0.0581561	total: 20.7s	remaining: 22.5s
# 480:	learn: 0.0581234	total: 20.8s	remaining: 22.4s
# 481:	learn: 0.0581004	total: 20.8s	remaining: 22.4s
# 482:	learn: 0.0580736	total: 20.9s	remaining: 22.3s
# 483:	learn: 0.0580356	total: 20.9s	remaining: 22.3s
# 484:	learn: 0.0580109	total: 21s	remaining: 22.3s
# 485:	learn: 0.0579890	total: 21s	remaining: 22.2s
# 486:	learn: 0.0579683	total: 21s	remaining: 22.2s
# 487:	learn: 0.0579306	total: 21.1s	remaining: 22.1s
# 488:	learn: 0.0579184	total: 21.1s	remaining: 22.1s
# 489:	learn: 0.0578989	total: 21.1s	remaining: 22s
# 490:	learn: 0.0578685	total: 21.2s	remaining: 22s
# 491:	learn: 0.0578342	total: 21.2s	remaining: 21.9s
# 492:	learn: 0.0578016	total: 21.3s	remaining: 21.9s
# 493:	learn: 0.0577729	total: 21.3s	remaining: 21.8s
# 494:	learn: 0.0577593	total: 21.3s	remaining: 21.8s
# 495:	learn: 0.0577341	total: 21.4s	remaining: 21.7s
# 496:	learn: 0.0577047	total: 21.4s	remaining: 21.7s
# 497:	learn: 0.0576761	total: 21.5s	remaining: 21.6s
# 498:	learn: 0.0576466	total: 21.5s	remaining: 21.6s
# 499:	learn: 0.0576362	total: 21.5s	remaining: 21.5s
# 500:	learn: 0.0576131	total: 21.6s	remaining: 21.5s
# 501:	learn: 0.0575978	total: 21.6s	remaining: 21.4s
# 502:	learn: 0.0575710	total: 21.6s	remaining: 21.4s
# 503:	learn: 0.0575436	total: 21.7s	remaining: 21.3s
# 504:	learn: 0.0575332	total: 21.7s	remaining: 21.3s
# 505:	learn: 0.0575186	total: 21.8s	remaining: 21.2s
# 506:	learn: 0.0574722	total: 21.8s	remaining: 21.2s
# 507:	learn: 0.0574528	total: 21.8s	remaining: 21.1s
# 508:	learn: 0.0574392	total: 21.9s	remaining: 21.1s
# 509:	learn: 0.0574077	total: 21.9s	remaining: 21.1s
# 510:	learn: 0.0573796	total: 22s	remaining: 21s
# 511:	learn: 0.0573579	total: 22s	remaining: 21s
# 512:	learn: 0.0573405	total: 22s	remaining: 20.9s
# 513:	learn: 0.0572927	total: 22.1s	remaining: 20.9s
# 514:	learn: 0.0572757	total: 22.1s	remaining: 20.8s
# 515:	learn: 0.0571417	total: 22.1s	remaining: 20.8s
# 516:	learn: 0.0571070	total: 22.2s	remaining: 20.7s
# 517:	learn: 0.0570808	total: 22.2s	remaining: 20.7s
# 518:	learn: 0.0570598	total: 22.3s	remaining: 20.6s
# 519:	learn: 0.0570330	total: 22.3s	remaining: 20.6s
# 520:	learn: 0.0569856	total: 22.3s	remaining: 20.5s
# 521:	learn: 0.0569697	total: 22.4s	remaining: 20.5s
# 522:	learn: 0.0569341	total: 22.4s	remaining: 20.5s
# 523:	learn: 0.0568892	total: 22.5s	remaining: 20.4s
# 524:	learn: 0.0568743	total: 22.5s	remaining: 20.4s
# 525:	learn: 0.0568517	total: 22.5s	remaining: 20.3s
# 526:	learn: 0.0568003	total: 22.6s	remaining: 20.3s
# 527:	learn: 0.0567727	total: 22.6s	remaining: 20.2s
# 528:	learn: 0.0567543	total: 22.7s	remaining: 20.2s
# 529:	learn: 0.0567298	total: 22.7s	remaining: 20.1s
# 530:	learn: 0.0566991	total: 22.7s	remaining: 20.1s
# 531:	learn: 0.0566925	total: 22.8s	remaining: 20s
# 532:	learn: 0.0566623	total: 22.8s	remaining: 20s
# 533:	learn: 0.0566365	total: 22.9s	remaining: 19.9s
# 534:	learn: 0.0566049	total: 22.9s	remaining: 19.9s
# 535:	learn: 0.0565775	total: 22.9s	remaining: 19.9s
# 536:	learn: 0.0565533	total: 23s	remaining: 19.8s
# 537:	learn: 0.0565371	total: 23s	remaining: 19.8s
# 538:	learn: 0.0565136	total: 23.1s	remaining: 19.7s
# 539:	learn: 0.0564881	total: 23.1s	remaining: 19.7s
# 540:	learn: 0.0564702	total: 23.1s	remaining: 19.6s
# 541:	learn: 0.0564593	total: 23.2s	remaining: 19.6s
# 542:	learn: 0.0564417	total: 23.2s	remaining: 19.5s
# 543:	learn: 0.0564203	total: 23.3s	remaining: 19.5s
# 544:	learn: 0.0563944	total: 23.3s	remaining: 19.4s
# 545:	learn: 0.0563716	total: 23.3s	remaining: 19.4s
# 546:	learn: 0.0563623	total: 23.4s	remaining: 19.4s
# 547:	learn: 0.0563464	total: 23.4s	remaining: 19.3s
# 548:	learn: 0.0563126	total: 23.4s	remaining: 19.3s
# 549:	learn: 0.0562858	total: 23.5s	remaining: 19.2s
# 550:	learn: 0.0562640	total: 23.5s	remaining: 19.2s
# 551:	learn: 0.0562309	total: 23.6s	remaining: 19.1s
# 552:	learn: 0.0561947	total: 23.6s	remaining: 19.1s
# 553:	learn: 0.0561790	total: 23.6s	remaining: 19s
# 554:	learn: 0.0561573	total: 23.7s	remaining: 19s
# 555:	learn: 0.0561370	total: 23.8s	remaining: 19s
# 556:	learn: 0.0561165	total: 23.9s	remaining: 19s
# 557:	learn: 0.0561044	total: 23.9s	remaining: 19s
# 558:	learn: 0.0560683	total: 24s	remaining: 18.9s
# 559:	learn: 0.0560512	total: 24.1s	remaining: 18.9s
# 560:	learn: 0.0560158	total: 24.1s	remaining: 18.9s
# 561:	learn: 0.0559851	total: 24.2s	remaining: 18.9s
# 562:	learn: 0.0559477	total: 24.3s	remaining: 18.8s
# 563:	learn: 0.0559194	total: 24.4s	remaining: 18.8s
# 564:	learn: 0.0559002	total: 24.4s	remaining: 18.8s
# 565:	learn: 0.0558796	total: 24.5s	remaining: 18.8s
# 566:	learn: 0.0558585	total: 24.6s	remaining: 18.8s
# 567:	learn: 0.0558373	total: 24.7s	remaining: 18.8s
# 568:	learn: 0.0558165	total: 24.8s	remaining: 18.8s
# 569:	learn: 0.0557758	total: 24.8s	remaining: 18.7s
# 570:	learn: 0.0557442	total: 24.9s	remaining: 18.7s
# 571:	learn: 0.0557171	total: 25s	remaining: 18.7s
# 572:	learn: 0.0556935	total: 25.1s	remaining: 18.7s
# 573:	learn: 0.0556270	total: 25.2s	remaining: 18.7s
# 574:	learn: 0.0555620	total: 25.2s	remaining: 18.7s
# 575:	learn: 0.0555424	total: 25.3s	remaining: 18.6s
# 576:	learn: 0.0555055	total: 25.4s	remaining: 18.6s
# 577:	learn: 0.0554607	total: 25.5s	remaining: 18.6s
# 578:	learn: 0.0554128	total: 25.6s	remaining: 18.6s
# 579:	learn: 0.0554018	total: 25.6s	remaining: 18.6s
# 580:	learn: 0.0553780	total: 25.7s	remaining: 18.6s
# 581:	learn: 0.0553476	total: 25.8s	remaining: 18.5s
# 582:	learn: 0.0553151	total: 25.9s	remaining: 18.5s
# 583:	learn: 0.0552887	total: 26s	remaining: 18.5s
# 584:	learn: 0.0552648	total: 26s	remaining: 18.5s
# 585:	learn: 0.0552456	total: 26.1s	remaining: 18.5s
# 586:	learn: 0.0552139	total: 26.2s	remaining: 18.4s
# 587:	learn: 0.0552006	total: 26.3s	remaining: 18.4s
# 588:	learn: 0.0551733	total: 26.4s	remaining: 18.4s
# 589:	learn: 0.0551288	total: 26.4s	remaining: 18.4s
# 590:	learn: 0.0550812	total: 26.5s	remaining: 18.3s
# 591:	learn: 0.0550606	total: 26.5s	remaining: 18.3s
# 592:	learn: 0.0550002	total: 26.5s	remaining: 18.2s
# 593:	learn: 0.0549805	total: 26.6s	remaining: 18.2s
# 594:	learn: 0.0549590	total: 26.6s	remaining: 18.1s
# 595:	learn: 0.0549199	total: 26.7s	remaining: 18.1s
# 596:	learn: 0.0548904	total: 26.7s	remaining: 18s
# 597:	learn: 0.0548486	total: 26.7s	remaining: 18s
# 598:	learn: 0.0548285	total: 26.8s	remaining: 17.9s
# 599:	learn: 0.0548070	total: 26.8s	remaining: 17.9s
# 600:	learn: 0.0547821	total: 26.9s	remaining: 17.8s
# 601:	learn: 0.0547634	total: 26.9s	remaining: 17.8s
# 602:	learn: 0.0547423	total: 26.9s	remaining: 17.7s
# 603:	learn: 0.0546745	total: 27s	remaining: 17.7s
# 604:	learn: 0.0546303	total: 27s	remaining: 17.6s
# 605:	learn: 0.0546183	total: 27.1s	remaining: 17.6s
# 606:	learn: 0.0546031	total: 27.1s	remaining: 17.6s
# 607:	learn: 0.0545801	total: 27.2s	remaining: 17.5s
# 608:	learn: 0.0545316	total: 27.2s	remaining: 17.5s
# 609:	learn: 0.0545158	total: 27.2s	remaining: 17.4s
# 610:	learn: 0.0544509	total: 27.3s	remaining: 17.4s
# 611:	learn: 0.0544059	total: 27.3s	remaining: 17.3s
# 612:	learn: 0.0543757	total: 27.4s	remaining: 17.3s
# 613:	learn: 0.0543411	total: 27.4s	remaining: 17.2s
# 614:	learn: 0.0543314	total: 27.4s	remaining: 17.2s
# 615:	learn: 0.0543161	total: 27.5s	remaining: 17.1s
# 616:	learn: 0.0542934	total: 27.5s	remaining: 17.1s
# 617:	learn: 0.0542669	total: 27.6s	remaining: 17s
# 618:	learn: 0.0542386	total: 27.6s	remaining: 17s
# 619:	learn: 0.0542181	total: 27.6s	remaining: 16.9s
# 620:	learn: 0.0541922	total: 27.7s	remaining: 16.9s
# 621:	learn: 0.0541711	total: 27.7s	remaining: 16.8s
# 622:	learn: 0.0541444	total: 27.8s	remaining: 16.8s
# 623:	learn: 0.0541111	total: 27.8s	remaining: 16.8s
# 624:	learn: 0.0540821	total: 27.8s	remaining: 16.7s
# 625:	learn: 0.0540587	total: 27.9s	remaining: 16.7s
# 626:	learn: 0.0540215	total: 27.9s	remaining: 16.6s
# 627:	learn: 0.0540052	total: 28s	remaining: 16.6s
# 628:	learn: 0.0539680	total: 28s	remaining: 16.5s
# 629:	learn: 0.0539488	total: 28s	remaining: 16.5s
# 630:	learn: 0.0539217	total: 28.1s	remaining: 16.4s
# 631:	learn: 0.0539021	total: 28.1s	remaining: 16.4s
# 632:	learn: 0.0538657	total: 28.2s	remaining: 16.3s
# 633:	learn: 0.0538269	total: 28.2s	remaining: 16.3s
# 634:	learn: 0.0537862	total: 28.2s	remaining: 16.2s
# 635:	learn: 0.0537545	total: 28.3s	remaining: 16.2s
# 636:	learn: 0.0537219	total: 28.3s	remaining: 16.1s
# 637:	learn: 0.0537069	total: 28.4s	remaining: 16.1s
# 638:	learn: 0.0536837	total: 28.4s	remaining: 16s
# 639:	learn: 0.0536600	total: 28.4s	remaining: 16s
# 640:	learn: 0.0536473	total: 28.5s	remaining: 15.9s
# 641:	learn: 0.0536255	total: 28.5s	remaining: 15.9s
# 642:	learn: 0.0536023	total: 28.6s	remaining: 15.9s
# 643:	learn: 0.0535705	total: 28.6s	remaining: 15.8s
# 644:	learn: 0.0535165	total: 28.6s	remaining: 15.8s
# 645:	learn: 0.0535008	total: 28.7s	remaining: 15.7s
# 646:	learn: 0.0534796	total: 28.7s	remaining: 15.7s
# 647:	learn: 0.0534506	total: 28.8s	remaining: 15.6s
# 648:	learn: 0.0534205	total: 28.8s	remaining: 15.6s
# 649:	learn: 0.0534023	total: 28.9s	remaining: 15.5s
# 650:	learn: 0.0533732	total: 28.9s	remaining: 15.5s
# 651:	learn: 0.0533543	total: 28.9s	remaining: 15.4s
# 652:	learn: 0.0533402	total: 29s	remaining: 15.4s
# 653:	learn: 0.0533206	total: 29s	remaining: 15.4s
# 654:	learn: 0.0532986	total: 29.1s	remaining: 15.3s
# 655:	learn: 0.0532686	total: 29.1s	remaining: 15.3s
# 656:	learn: 0.0532500	total: 29.1s	remaining: 15.2s
# 657:	learn: 0.0532239	total: 29.2s	remaining: 15.2s
# 658:	learn: 0.0531782	total: 29.2s	remaining: 15.1s
# 659:	learn: 0.0531625	total: 29.3s	remaining: 15.1s
# 660:	learn: 0.0531453	total: 29.3s	remaining: 15s
# 661:	learn: 0.0531291	total: 29.3s	remaining: 15s
# 662:	learn: 0.0530961	total: 29.4s	remaining: 14.9s
# 663:	learn: 0.0530881	total: 29.4s	remaining: 14.9s
# 664:	learn: 0.0530432	total: 29.5s	remaining: 14.8s
# 665:	learn: 0.0530197	total: 29.5s	remaining: 14.8s
# 666:	learn: 0.0529855	total: 29.5s	remaining: 14.7s
# 667:	learn: 0.0529661	total: 29.6s	remaining: 14.7s
# 668:	learn: 0.0529463	total: 29.6s	remaining: 14.7s
# 669:	learn: 0.0529259	total: 29.6s	remaining: 14.6s
# 670:	learn: 0.0528937	total: 29.7s	remaining: 14.6s
# 671:	learn: 0.0528721	total: 29.7s	remaining: 14.5s
# 672:	learn: 0.0528565	total: 29.8s	remaining: 14.5s
# 673:	learn: 0.0528401	total: 29.8s	remaining: 14.4s
# 674:	learn: 0.0528188	total: 29.8s	remaining: 14.4s
# 675:	learn: 0.0528009	total: 29.9s	remaining: 14.3s
# 676:	learn: 0.0527694	total: 29.9s	remaining: 14.3s
# 677:	learn: 0.0527524	total: 30s	remaining: 14.2s
# 678:	learn: 0.0527282	total: 30s	remaining: 14.2s
# 679:	learn: 0.0527168	total: 30.1s	remaining: 14.1s
# 680:	learn: 0.0526980	total: 30.1s	remaining: 14.1s
# 681:	learn: 0.0526638	total: 30.1s	remaining: 14.1s
# 682:	learn: 0.0526533	total: 30.2s	remaining: 14s
# 683:	learn: 0.0526296	total: 30.2s	remaining: 14s
# 684:	learn: 0.0526103	total: 30.3s	remaining: 13.9s
# 685:	learn: 0.0525950	total: 30.3s	remaining: 13.9s
# 686:	learn: 0.0525410	total: 30.3s	remaining: 13.8s
# 687:	learn: 0.0525239	total: 30.4s	remaining: 13.8s
# 688:	learn: 0.0524949	total: 30.4s	remaining: 13.7s
# 689:	learn: 0.0524867	total: 30.4s	remaining: 13.7s
# 690:	learn: 0.0524682	total: 30.5s	remaining: 13.6s
# 691:	learn: 0.0524526	total: 30.5s	remaining: 13.6s
# 692:	learn: 0.0523713	total: 30.6s	remaining: 13.5s
# 693:	learn: 0.0523453	total: 30.6s	remaining: 13.5s
# 694:	learn: 0.0523293	total: 30.7s	remaining: 13.5s
# 695:	learn: 0.0523155	total: 30.7s	remaining: 13.4s
# 696:	learn: 0.0522847	total: 30.7s	remaining: 13.4s
# 697:	learn: 0.0522651	total: 30.8s	remaining: 13.3s
# 698:	learn: 0.0522406	total: 30.8s	remaining: 13.3s
# 699:	learn: 0.0522232	total: 30.8s	remaining: 13.2s
# 700:	learn: 0.0522018	total: 30.9s	remaining: 13.2s
# 701:	learn: 0.0521892	total: 30.9s	remaining: 13.1s
# 702:	learn: 0.0521765	total: 31s	remaining: 13.1s
# 703:	learn: 0.0521592	total: 31s	remaining: 13s
# 704:	learn: 0.0521137	total: 31s	remaining: 13s
# 705:	learn: 0.0520964	total: 31.1s	remaining: 12.9s
# 706:	learn: 0.0520820	total: 31.1s	remaining: 12.9s
# 707:	learn: 0.0520674	total: 31.2s	remaining: 12.8s
# 708:	learn: 0.0520442	total: 31.2s	remaining: 12.8s
# 709:	learn: 0.0520305	total: 31.2s	remaining: 12.8s
# 710:	learn: 0.0520161	total: 31.3s	remaining: 12.7s
# 711:	learn: 0.0519925	total: 31.3s	remaining: 12.7s
# 712:	learn: 0.0519747	total: 31.4s	remaining: 12.6s
# 713:	learn: 0.0519558	total: 31.4s	remaining: 12.6s
# 714:	learn: 0.0519174	total: 31.4s	remaining: 12.5s
# 715:	learn: 0.0518969	total: 31.5s	remaining: 12.5s
# 716:	learn: 0.0518461	total: 31.5s	remaining: 12.4s
# 717:	learn: 0.0518223	total: 31.6s	remaining: 12.4s
# 718:	learn: 0.0518017	total: 31.6s	remaining: 12.3s
# 719:	learn: 0.0517737	total: 31.6s	remaining: 12.3s
# 720:	learn: 0.0517105	total: 31.7s	remaining: 12.3s
# 721:	learn: 0.0516995	total: 31.7s	remaining: 12.2s
# 722:	learn: 0.0516676	total: 31.8s	remaining: 12.2s
# 723:	learn: 0.0516434	total: 31.8s	remaining: 12.1s
# 724:	learn: 0.0516198	total: 31.8s	remaining: 12.1s
# 725:	learn: 0.0516014	total: 31.9s	remaining: 12s
# 726:	learn: 0.0515731	total: 31.9s	remaining: 12s
# 727:	learn: 0.0515507	total: 32s	remaining: 11.9s
# 728:	learn: 0.0515177	total: 32s	remaining: 11.9s
# 729:	learn: 0.0514772	total: 32s	remaining: 11.8s
# 730:	learn: 0.0514668	total: 32.1s	remaining: 11.8s
# 731:	learn: 0.0514459	total: 32.1s	remaining: 11.8s
# 732:	learn: 0.0514130	total: 32.2s	remaining: 11.7s
# 733:	learn: 0.0513970	total: 32.2s	remaining: 11.7s
# 734:	learn: 0.0513846	total: 32.2s	remaining: 11.6s
# 735:	learn: 0.0513583	total: 32.3s	remaining: 11.6s
# 736:	learn: 0.0513478	total: 32.3s	remaining: 11.5s
# 737:	learn: 0.0513326	total: 32.4s	remaining: 11.5s
# 738:	learn: 0.0513111	total: 32.4s	remaining: 11.4s
# 739:	learn: 0.0512969	total: 32.4s	remaining: 11.4s
# 740:	learn: 0.0512577	total: 32.5s	remaining: 11.3s
# 741:	learn: 0.0512259	total: 32.5s	remaining: 11.3s
# 742:	learn: 0.0512167	total: 32.5s	remaining: 11.3s
# 743:	learn: 0.0511940	total: 32.6s	remaining: 11.2s
# 744:	learn: 0.0511726	total: 32.6s	remaining: 11.2s
# 745:	learn: 0.0511324	total: 32.7s	remaining: 11.1s
# 746:	learn: 0.0511199	total: 32.7s	remaining: 11.1s
# 747:	learn: 0.0510994	total: 32.7s	remaining: 11s
# 748:	learn: 0.0510861	total: 32.8s	remaining: 11s
# 749:	learn: 0.0510717	total: 32.8s	remaining: 10.9s
# 750:	learn: 0.0510471	total: 32.9s	remaining: 10.9s
# 751:	learn: 0.0510313	total: 32.9s	remaining: 10.8s
# 752:	learn: 0.0510141	total: 32.9s	remaining: 10.8s
# 753:	learn: 0.0509855	total: 33s	remaining: 10.8s
# 754:	learn: 0.0509678	total: 33s	remaining: 10.7s
# 755:	learn: 0.0509425	total: 33.1s	remaining: 10.7s
# 756:	learn: 0.0509340	total: 33.1s	remaining: 10.6s
# 757:	learn: 0.0509173	total: 33.1s	remaining: 10.6s
# 758:	learn: 0.0509039	total: 33.2s	remaining: 10.5s
# 759:	learn: 0.0508933	total: 33.2s	remaining: 10.5s
# 760:	learn: 0.0508829	total: 33.3s	remaining: 10.4s
# 761:	learn: 0.0508655	total: 33.3s	remaining: 10.4s
# 762:	learn: 0.0508403	total: 33.3s	remaining: 10.4s
# 763:	learn: 0.0508254	total: 33.4s	remaining: 10.3s
# 764:	learn: 0.0508066	total: 33.4s	remaining: 10.3s
# 765:	learn: 0.0507994	total: 33.5s	remaining: 10.2s
# 766:	learn: 0.0507762	total: 33.5s	remaining: 10.2s
# 767:	learn: 0.0507586	total: 33.5s	remaining: 10.1s
# 768:	learn: 0.0507411	total: 33.6s	remaining: 10.1s
# 769:	learn: 0.0507064	total: 33.6s	remaining: 10s
# 770:	learn: 0.0506781	total: 33.7s	remaining: 10s
# 771:	learn: 0.0506481	total: 33.7s	remaining: 9.95s
# 772:	learn: 0.0506364	total: 33.7s	remaining: 9.9s
# 773:	learn: 0.0506278	total: 33.8s	remaining: 9.86s
# 774:	learn: 0.0505943	total: 33.8s	remaining: 9.81s
# 775:	learn: 0.0505770	total: 33.8s	remaining: 9.77s
# 776:	learn: 0.0505509	total: 33.9s	remaining: 9.73s
# 777:	learn: 0.0505209	total: 33.9s	remaining: 9.68s
# 778:	learn: 0.0505063	total: 34s	remaining: 9.63s
# 779:	learn: 0.0504893	total: 34s	remaining: 9.59s
# 780:	learn: 0.0504363	total: 34s	remaining: 9.54s
# 781:	learn: 0.0504153	total: 34.1s	remaining: 9.5s
# 782:	learn: 0.0503959	total: 34.1s	remaining: 9.46s
# 783:	learn: 0.0503781	total: 34.2s	remaining: 9.41s
# 784:	learn: 0.0503632	total: 34.2s	remaining: 9.37s
# 785:	learn: 0.0503517	total: 34.2s	remaining: 9.32s
# 786:	learn: 0.0503385	total: 34.3s	remaining: 9.28s
# 787:	learn: 0.0503201	total: 34.3s	remaining: 9.23s
# 788:	learn: 0.0503047	total: 34.4s	remaining: 9.19s
# 789:	learn: 0.0502873	total: 34.4s	remaining: 9.15s
# 790:	learn: 0.0502539	total: 34.4s	remaining: 9.1s
# 791:	learn: 0.0502257	total: 34.5s	remaining: 9.06s
# 792:	learn: 0.0502060	total: 34.5s	remaining: 9.01s
# 793:	learn: 0.0501843	total: 34.6s	remaining: 8.97s
# 794:	learn: 0.0501419	total: 34.6s	remaining: 8.92s
# 795:	learn: 0.0501209	total: 34.6s	remaining: 8.88s
# 796:	learn: 0.0500924	total: 34.7s	remaining: 8.83s
# 797:	learn: 0.0500702	total: 34.7s	remaining: 8.79s
# 798:	learn: 0.0500574	total: 34.8s	remaining: 8.75s
# 799:	learn: 0.0500195	total: 34.8s	remaining: 8.7s
# 800:	learn: 0.0500046	total: 34.8s	remaining: 8.66s
# 801:	learn: 0.0499933	total: 34.9s	remaining: 8.61s
# 802:	learn: 0.0499823	total: 34.9s	remaining: 8.57s
# 803:	learn: 0.0499505	total: 35s	remaining: 8.52s
# 804:	learn: 0.0499444	total: 35s	remaining: 8.48s
# 805:	learn: 0.0499250	total: 35.1s	remaining: 8.44s
# 806:	learn: 0.0499078	total: 35.1s	remaining: 8.39s
# 807:	learn: 0.0498916	total: 35.1s	remaining: 8.35s
# 808:	learn: 0.0498615	total: 35.2s	remaining: 8.31s
# 809:	learn: 0.0498408	total: 35.2s	remaining: 8.26s
# 810:	learn: 0.0498266	total: 35.3s	remaining: 8.22s
# 811:	learn: 0.0498109	total: 35.3s	remaining: 8.17s
# 812:	learn: 0.0497760	total: 35.3s	remaining: 8.13s
# 813:	learn: 0.0497598	total: 35.4s	remaining: 8.09s
# 814:	learn: 0.0497352	total: 35.4s	remaining: 8.04s
# 815:	learn: 0.0497132	total: 35.5s	remaining: 8s
# 816:	learn: 0.0497000	total: 35.5s	remaining: 7.95s
# 817:	learn: 0.0496836	total: 35.5s	remaining: 7.91s
# 818:	learn: 0.0496615	total: 35.6s	remaining: 7.86s
# 819:	learn: 0.0496491	total: 35.6s	remaining: 7.82s
# 820:	learn: 0.0496222	total: 35.7s	remaining: 7.77s
# 821:	learn: 0.0496059	total: 35.7s	remaining: 7.73s
# 822:	learn: 0.0495878	total: 35.7s	remaining: 7.68s
# 823:	learn: 0.0495717	total: 35.8s	remaining: 7.64s
# 824:	learn: 0.0495530	total: 35.8s	remaining: 7.59s
# 825:	learn: 0.0495247	total: 35.8s	remaining: 7.55s
# 826:	learn: 0.0495095	total: 35.9s	remaining: 7.51s
# 827:	learn: 0.0494999	total: 35.9s	remaining: 7.46s
# 828:	learn: 0.0494797	total: 36s	remaining: 7.42s
# 829:	learn: 0.0494431	total: 36s	remaining: 7.37s
# 830:	learn: 0.0494267	total: 36s	remaining: 7.33s
# 831:	learn: 0.0494003	total: 36.1s	remaining: 7.29s
# 832:	learn: 0.0493869	total: 36.1s	remaining: 7.24s
# 833:	learn: 0.0493746	total: 36.2s	remaining: 7.2s
# 834:	learn: 0.0493605	total: 36.2s	remaining: 7.15s
# 835:	learn: 0.0493196	total: 36.2s	remaining: 7.11s
# 836:	learn: 0.0492964	total: 36.3s	remaining: 7.07s
# 837:	learn: 0.0492645	total: 36.3s	remaining: 7.03s
# 838:	learn: 0.0492573	total: 36.4s	remaining: 6.99s
# 839:	learn: 0.0492243	total: 36.5s	remaining: 6.95s
# 840:	learn: 0.0491924	total: 36.6s	remaining: 6.92s
# 841:	learn: 0.0491751	total: 36.7s	remaining: 6.88s
# 842:	learn: 0.0491543	total: 36.7s	remaining: 6.84s
# 843:	learn: 0.0491415	total: 36.8s	remaining: 6.8s
# 844:	learn: 0.0491194	total: 36.9s	remaining: 6.77s
# 845:	learn: 0.0490966	total: 37s	remaining: 6.73s
# 846:	learn: 0.0490834	total: 37s	remaining: 6.69s
# 847:	learn: 0.0490711	total: 37.1s	remaining: 6.65s
# 848:	learn: 0.0490603	total: 37.2s	remaining: 6.62s
# 849:	learn: 0.0490290	total: 37.3s	remaining: 6.58s
# 850:	learn: 0.0490188	total: 37.3s	remaining: 6.54s
# 851:	learn: 0.0490126	total: 37.4s	remaining: 6.5s
# 852:	learn: 0.0489699	total: 37.5s	remaining: 6.46s
# 853:	learn: 0.0489555	total: 37.6s	remaining: 6.42s
# 854:	learn: 0.0489454	total: 37.7s	remaining: 6.38s
# 855:	learn: 0.0489011	total: 37.8s	remaining: 6.35s
# 856:	learn: 0.0488903	total: 37.8s	remaining: 6.31s
# 857:	learn: 0.0488816	total: 37.9s	remaining: 6.27s
# 858:	learn: 0.0488595	total: 38s	remaining: 6.23s
# 859:	learn: 0.0488402	total: 38.1s	remaining: 6.2s
# 860:	learn: 0.0488301	total: 38.1s	remaining: 6.16s
# 861:	learn: 0.0487995	total: 38.2s	remaining: 6.12s
# 862:	learn: 0.0487675	total: 38.3s	remaining: 6.08s
# 863:	learn: 0.0487534	total: 38.4s	remaining: 6.04s
# 864:	learn: 0.0487364	total: 38.5s	remaining: 6s
# 865:	learn: 0.0487122	total: 38.6s	remaining: 5.97s
# 866:	learn: 0.0486922	total: 38.6s	remaining: 5.93s
# 867:	learn: 0.0486722	total: 38.7s	remaining: 5.89s
# 868:	learn: 0.0486574	total: 38.8s	remaining: 5.85s
# 869:	learn: 0.0486400	total: 38.9s	remaining: 5.81s
# 870:	learn: 0.0485931	total: 39s	remaining: 5.77s
# 871:	learn: 0.0485799	total: 39s	remaining: 5.73s
# 872:	learn: 0.0485482	total: 39.1s	remaining: 5.68s
# 873:	learn: 0.0485430	total: 39.1s	remaining: 5.64s
# 874:	learn: 0.0485346	total: 39.2s	remaining: 5.59s
# 875:	learn: 0.0484988	total: 39.2s	remaining: 5.55s
# 876:	learn: 0.0484873	total: 39.2s	remaining: 5.5s
# 877:	learn: 0.0484791	total: 39.3s	remaining: 5.46s
# 878:	learn: 0.0484589	total: 39.3s	remaining: 5.41s
# 879:	learn: 0.0484330	total: 39.4s	remaining: 5.37s
# 880:	learn: 0.0484180	total: 39.4s	remaining: 5.32s
# 881:	learn: 0.0483893	total: 39.5s	remaining: 5.28s
# 882:	learn: 0.0483633	total: 39.5s	remaining: 5.23s
# 883:	learn: 0.0483395	total: 39.5s	remaining: 5.19s
# 884:	learn: 0.0483008	total: 39.6s	remaining: 5.14s
# 885:	learn: 0.0482773	total: 39.6s	remaining: 5.1s
# 886:	learn: 0.0482668	total: 39.6s	remaining: 5.05s
# 887:	learn: 0.0482560	total: 39.7s	remaining: 5s
# 888:	learn: 0.0482435	total: 39.7s	remaining: 4.96s
# 889:	learn: 0.0482047	total: 39.8s	remaining: 4.91s
# 890:	learn: 0.0481893	total: 39.8s	remaining: 4.87s
# 891:	learn: 0.0481676	total: 39.8s	remaining: 4.82s
# 892:	learn: 0.0481485	total: 39.9s	remaining: 4.78s
# 893:	learn: 0.0481384	total: 39.9s	remaining: 4.73s
# 894:	learn: 0.0481269	total: 40s	remaining: 4.69s
# 895:	learn: 0.0481135	total: 40s	remaining: 4.64s
# 896:	learn: 0.0480864	total: 40s	remaining: 4.6s
# 897:	learn: 0.0480704	total: 40.1s	remaining: 4.55s
# 898:	learn: 0.0480593	total: 40.1s	remaining: 4.5s
# 899:	learn: 0.0480489	total: 40.1s	remaining: 4.46s
# 900:	learn: 0.0480371	total: 40.2s	remaining: 4.41s
# 901:	learn: 0.0480242	total: 40.2s	remaining: 4.37s
# 902:	learn: 0.0479933	total: 40.3s	remaining: 4.32s
# 903:	learn: 0.0479823	total: 40.3s	remaining: 4.28s
# 904:	learn: 0.0479675	total: 40.3s	remaining: 4.23s
# 905:	learn: 0.0479486	total: 40.4s	remaining: 4.19s
# 906:	learn: 0.0479315	total: 40.4s	remaining: 4.14s
# 907:	learn: 0.0478773	total: 40.5s	remaining: 4.1s
# 908:	learn: 0.0478659	total: 40.5s	remaining: 4.05s
# 909:	learn: 0.0478350	total: 40.5s	remaining: 4.01s
# 910:	learn: 0.0477956	total: 40.6s	remaining: 3.96s
# 911:	learn: 0.0477649	total: 40.6s	remaining: 3.92s
# 912:	learn: 0.0477417	total: 40.7s	remaining: 3.87s
# 913:	learn: 0.0477291	total: 40.7s	remaining: 3.83s
# 914:	learn: 0.0477123	total: 40.7s	remaining: 3.78s
# 915:	learn: 0.0477032	total: 40.8s	remaining: 3.74s
# 916:	learn: 0.0476877	total: 40.8s	remaining: 3.69s
# 917:	learn: 0.0476804	total: 40.8s	remaining: 3.65s
# 918:	learn: 0.0476646	total: 40.9s	remaining: 3.6s
# 919:	learn: 0.0476097	total: 40.9s	remaining: 3.56s
# 920:	learn: 0.0475784	total: 41s	remaining: 3.51s
# 921:	learn: 0.0475461	total: 41s	remaining: 3.47s
# 922:	learn: 0.0475197	total: 41.1s	remaining: 3.42s
# 923:	learn: 0.0475017	total: 41.1s	remaining: 3.38s
# 924:	learn: 0.0474781	total: 41.1s	remaining: 3.33s
# 925:	learn: 0.0474513	total: 41.2s	remaining: 3.29s
# 926:	learn: 0.0474411	total: 41.2s	remaining: 3.24s
# 927:	learn: 0.0474236	total: 41.2s	remaining: 3.2s
# 928:	learn: 0.0474078	total: 41.3s	remaining: 3.16s
# 929:	learn: 0.0473783	total: 41.3s	remaining: 3.11s
# 930:	learn: 0.0473578	total: 41.4s	remaining: 3.07s
# 931:	learn: 0.0473432	total: 41.4s	remaining: 3.02s
# 932:	learn: 0.0473336	total: 41.5s	remaining: 2.98s
# 933:	learn: 0.0473076	total: 41.5s	remaining: 2.93s
# 934:	learn: 0.0472670	total: 41.5s	remaining: 2.89s
# 935:	learn: 0.0472572	total: 41.6s	remaining: 2.84s
# 936:	learn: 0.0472485	total: 41.6s	remaining: 2.8s
# 937:	learn: 0.0472172	total: 41.7s	remaining: 2.75s
# 938:	learn: 0.0471944	total: 41.7s	remaining: 2.71s
# 939:	learn: 0.0471842	total: 41.7s	remaining: 2.66s
# 940:	learn: 0.0471767	total: 41.8s	remaining: 2.62s
# 941:	learn: 0.0471639	total: 41.8s	remaining: 2.58s
# 942:	learn: 0.0471401	total: 41.9s	remaining: 2.53s
# 943:	learn: 0.0471133	total: 41.9s	remaining: 2.48s
# 944:	learn: 0.0470952	total: 41.9s	remaining: 2.44s
# 945:	learn: 0.0470735	total: 42s	remaining: 2.4s
# 946:	learn: 0.0470559	total: 42s	remaining: 2.35s
# 947:	learn: 0.0470450	total: 42.1s	remaining: 2.31s
# 948:	learn: 0.0470220	total: 42.1s	remaining: 2.26s
# 949:	learn: 0.0470027	total: 42.1s	remaining: 2.22s
# 950:	learn: 0.0469819	total: 42.2s	remaining: 2.17s
# 951:	learn: 0.0469755	total: 42.2s	remaining: 2.13s
# 952:	learn: 0.0469684	total: 42.3s	remaining: 2.08s
# 953:	learn: 0.0469353	total: 42.3s	remaining: 2.04s
# 954:	learn: 0.0469109	total: 42.3s	remaining: 2s
# 955:	learn: 0.0468930	total: 42.4s	remaining: 1.95s
# 956:	learn: 0.0468674	total: 42.4s	remaining: 1.91s
# 957:	learn: 0.0468421	total: 42.5s	remaining: 1.86s
# 958:	learn: 0.0468208	total: 42.5s	remaining: 1.82s
# 959:	learn: 0.0467976	total: 42.5s	remaining: 1.77s
# 960:	learn: 0.0467820	total: 42.6s	remaining: 1.73s
# 961:	learn: 0.0467677	total: 42.6s	remaining: 1.68s
# 962:	learn: 0.0467549	total: 42.7s	remaining: 1.64s
# 963:	learn: 0.0467298	total: 42.7s	remaining: 1.59s
# 964:	learn: 0.0467135	total: 42.8s	remaining: 1.55s
# 965:	learn: 0.0466618	total: 42.8s	remaining: 1.51s
# 966:	learn: 0.0466484	total: 42.8s	remaining: 1.46s
# 967:	learn: 0.0466247	total: 42.9s	remaining: 1.42s
# 968:	learn: 0.0466051	total: 42.9s	remaining: 1.37s
# 969:	learn: 0.0465891	total: 43s	remaining: 1.33s
# 970:	learn: 0.0465634	total: 43s	remaining: 1.28s
# 971:	learn: 0.0465474	total: 43s	remaining: 1.24s
# 972:	learn: 0.0465295	total: 43.1s	remaining: 1.2s
# 973:	learn: 0.0465078	total: 43.1s	remaining: 1.15s
# 974:	learn: 0.0464806	total: 43.2s	remaining: 1.11s
# 975:	learn: 0.0464520	total: 43.2s	remaining: 1.06s
# 976:	learn: 0.0464305	total: 43.2s	remaining: 1.02s
# 977:	learn: 0.0464082	total: 43.3s	remaining: 974ms
# 978:	learn: 0.0463837	total: 43.3s	remaining: 930ms
# 979:	learn: 0.0463657	total: 43.4s	remaining: 885ms
# 980:	learn: 0.0463568	total: 43.4s	remaining: 841ms
# 981:	learn: 0.0463300	total: 43.5s	remaining: 797ms
# 982:	learn: 0.0463179	total: 43.5s	remaining: 752ms
# 983:	learn: 0.0462646	total: 43.5s	remaining: 708ms
# 984:	learn: 0.0462481	total: 43.6s	remaining: 664ms
# 985:	learn: 0.0462400	total: 43.6s	remaining: 619ms
# 986:	learn: 0.0462256	total: 43.7s	remaining: 575ms
# 987:	learn: 0.0462158	total: 43.7s	remaining: 531ms
# 988:	learn: 0.0461858	total: 43.7s	remaining: 487ms
# 989:	learn: 0.0461508	total: 43.8s	remaining: 442ms
# 990:	learn: 0.0461270	total: 43.8s	remaining: 398ms
# 991:	learn: 0.0461116	total: 43.9s	remaining: 354ms
# 992:	learn: 0.0460971	total: 43.9s	remaining: 310ms
# 993:	learn: 0.0460823	total: 43.9s	remaining: 265ms
# 994:	learn: 0.0460764	total: 44s	remaining: 221ms
# 995:	learn: 0.0460601	total: 44s	remaining: 177ms
# 996:	learn: 0.0460442	total: 44.1s	remaining: 133ms
# 997:	learn: 0.0460204	total: 44.1s	remaining: 88.4ms
# 998:	learn: 0.0459987	total: 44.1s	remaining: 44.2ms
# 999:	learn: 0.0459860	total: 44.2s	remaining: 0us

# %%
X_test2.head(3)
# Out:
#             alpha      delta         u         g         r         i  \
# 15727  239.353964  55.391238  20.15380  19.74234  19.31396  19.29645
# 70184  341.154029   5.727165  22.32511  21.90339  21.75924  21.40544
# 26773  181.324623  49.883392  21.87684  20.41339  19.81394  19.56042
#
#               z  cam_col  redshift    plate      MJD  fiber_ID
# 15727  19.38161        5  1.143417   8413.0  57897.0     681.0
# 70184  21.48124        1  0.836712  11305.0  58449.0     574.0
# 26773  19.30338        3 -0.000173   2919.0  54537.0     195.0

# %%
# Get predicted classes
predict = model.predict(X_test2)
pred = pd.DataFrame(predict)
pred.head()
# Out:
#         0
# 0     QSO
# 1     QSO
# 2    STAR
# 3  GALAXY
# 4  GALAXY

# %%
X_test.head()
# Out:
#             alpha      delta         u         g         r         i  \
# 15727  239.353964  55.391238  20.15380  19.74234  19.31396  19.29645
# 70184  341.154029   5.727165  22.32511  21.90339  21.75924  21.40544
# 26773  181.324623  49.883392  21.87684  20.41339  19.81394  19.56042
# 78435  129.420965  18.601070  19.64541  18.14898  17.45370  17.09736
# 20544  146.375642  19.259911  19.75237  18.76292  18.19900  17.85236
#
#               z  cam_col   class  redshift    plate      MJD  fiber_ID
# 15727  19.38161        5     QSO  1.143417   8413.0  57897.0     681.0
# 70184  21.48124        1     QSO  0.836712  11305.0  58449.0     574.0
# 26773  19.30338        3    STAR -0.000173   2919.0  54537.0     195.0
# 78435  16.77880        1  GALAXY  0.095100   2275.0  53709.0      68.0
# 20544  17.75901        2  GALAXY  0.149367   2362.0  53759.0     251.0

# %%
X_test.head()
# Out:
#             alpha      delta         u         g         r         i  \
# 15727  239.353964  55.391238  20.15380  19.74234  19.31396  19.29645
# 70184  341.154029   5.727165  22.32511  21.90339  21.75924  21.40544
# 26773  181.324623  49.883392  21.87684  20.41339  19.81394  19.56042
# 78435  129.420965  18.601070  19.64541  18.14898  17.45370  17.09736
# 20544  146.375642  19.259911  19.75237  18.76292  18.19900  17.85236
#
#               z  cam_col   class  redshift    plate      MJD  fiber_ID
# 15727  19.38161        5     QSO  1.143417   8413.0  57897.0     681.0
# 70184  21.48124        1     QSO  0.836712  11305.0  58449.0     574.0
# 26773  19.30338        3    STAR -0.000173   2919.0  54537.0     195.0
# 78435  16.77880        1  GALAXY  0.095100   2275.0  53709.0      68.0
# 20544  17.75901        2  GALAXY  0.149367   2362.0  53759.0     251.0

# %%
X.iloc[[75721,80184,19864,76699,92991]]
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 75721  1.237679e+18   16.956890   3.646130  23.33542  21.95143  20.48149
# 80184  1.237662e+18  240.063240   6.134131  17.86033  16.79228  16.43001
# 19864  1.237679e+18   30.887222   1.188710  18.18911  16.89469  16.42161
# 76699  1.237668e+18  247.594401  10.887780  24.99961  21.71203  21.47148
# 92991  1.237679e+18   18.896451  -5.261330  23.76648  21.79737  20.69543
#
#               i         z  run_ID  cam_col  field_ID   spec_obj_ID   class  \
# 75721  19.60300  19.13094    7712        6       442  4.855017e+18  GALAXY
# 80184  16.30923  16.25873    3894        1       243  2.448928e+18    STAR
# 19864  16.24627  16.18549    7717        1       536  8.255357e+18    STAR
# 76699  21.30532  21.29109    5323        1       134  4.577999e+18    STAR
# 92991  20.23403  19.97464    7881        3       148  8.910472e+18    STAR
#
#        redshift  plate    MJD  fiber_ID
# 75721  0.506237   4312  55511       495
# 80184  0.000345   2175  54612       348
# 19864  0.000004   7332  56683       943
# 76699 -0.000291   4066  55444       326
# 92991 -0.000136   7914  57331       363

# %%
from catboost.utils import eval_metric

# %%
#res = pd.DataFrame(y_test).join( pd.DataFrame(predict))
# test_pool = Pool( y_test, predict)
metric = eval_metric(y_test, predict, 'Precision')
print(metric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-5f827eb6a097> in <cell line: 3>()
#       1 #res = pd.DataFrame(y_test).join( pd.DataFrame(predict))
#       2 # test_pool = Pool( y_test, predict)
# ----> 3 metric = eval_metric(y_test, predict, 'Precision')
#       4 print(metric)
#
# /usr/local/lib/python3.10/dist-packages/catboost/utils.py in eval_metric(label, approx, metric, weight, group_id, group_weight, subgroup_id, pairs, thread_count)
#     291     """
#     292     if len(label) > 0:
# --> 293         label = np.transpose(label) if isinstance(label[0], ARRAY_TYPES) else [label]
#     294     if len(approx) == 0:
#     295         approx = [[]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
for metric in ('Precision', 'Recall', 'F1'):
    print(metric)
    values = eval_metric(y_test, predict, metric)
    for model, value in zip(clf.classes_, values):
        print(f'class={cls}: {value:.4f}')
    print()
# Out:
# Precision
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 for metric in ('Precision', 'Recall', 'F1'):
#       2     print(metric)
# ----> 3     values = eval_metric(y_test, predict, metric)
#       4     for model, value in zip(clf.classes_, values):
#       5         print(f'class={cls}: {value:.4f}')
#
# File ~/bin/anaconda/lib/python3.10/site-packages/catboost/utils.py:293, in eval_metric(label, approx, metric, weight, group_id, group_weight, subgroup_id, pairs, thread_count)
#     249 """
#     250 Evaluate metrics with raw approxes and labels.
#     251
#    (...)
#     290 metric results : list with metric values.
#     291 """
#     292 if len(label) > 0:
# --> 293     label = np.transpose(label) if isinstance(label[0], ARRAY_TYPES) else [label]
#     294 if len(approx) == 0:
#     295     approx = [[]]
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/bin/anaconda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
model.save_model('astra.cbm')

# %%
# !ls
# Out:
# astra.cbm  astra.json  catboost_info  sample_data

# %%
X_test.to_csv('astra.csv')

# %%
ff = model.get_feature_importance()
ff
# Out:
# array([ 0.27624387,  0.27778713,  0.1622283 ,  0.10247422,  0.1581494 ,
#         0.25616265,  0.21896545,  0.29039967,  0.27757768,  0.35941504,
#         0.16894315, 91.3056414 ,  5.55423445,  0.15600785,  0.17002827,
#         0.26574147])

# %%
nn = model.get_feature_names()
nn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 nn = model.get_feature_names()
#       2 nn
#
# AttributeError: 'CatBoostClassifier' object has no attribute 'get_feature_names'
